# %% [markdown]
# <a href="https://colab.research.google.com/github/BellyTheMagnificent/CIFAR-10/blob/master/%20Classification%20by%20Fully%20Connected%20Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <figure>
# <center><img align='center' src='https://github.com/BellyTheMagnificent/CIFAR-10/blob/master/content/NYPlogo.jpg?raw=true' />
# </center></figure>
#
#
#
#
#
# # **CIFAR-10 classification by Fully Connected Network**
#
# -----------------
# ## Authors
# * LEE CHUN WAI
# * NG CHONG SOON
#
#
# ## Objectives
#
#
#
# *   Design fully connected neural network on tensorflow 2.0 and Keras
# *   Experiment on using regularization to improve model performance
# *   Explore how width and depth of the neural network can impact to model's performance

# %% [markdown]
# # Introduction
#
# In image classification task, we have seen neural networks performing exceptionally on MNIST dataset. Therefore in this notebook, we would like to explore what type of performances we would get if classifying colored images.
#
# The [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset consists of 80 million color images (32x32). This dataset is used for image recognition and is collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.
#
# We will perform classification on a subset of the CIFAR-10 dataset (60000 images). The dataset is divided into train and test set. There are 10 classes in this dataset.
#
# Tensorflow Keras will be used throughout this notebook as part of this learning journey.

# %% [markdown]
# # Loading, understanding, and processing data

# %% [markdown]
# ## Import libraries
#
# Import the required libaries as follows
#
# *   numpy - for some matrix math outside of TensorFlow
# *   os - read files and directory structure
# *   matplotlib - plot graph in python
# *   pickle - read data from cifar10 datasets
# *   Scipy, PIL - Process input image for prediction
# *   sklearn - Rescale input data

# %%
try:
  # Use the %tensorflow_version magic if in colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
import numpy as np
import os, datetime, math, random, collections, h5py
import tensorflow as tf
from matplotlib import pyplot as plt
from PIL import Image
from scipy import ndimage
from tensorflow.keras.layers import Dropout, Dense, Flatten, Activation, LeakyReLU, PReLU, ReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, optimizers, regularizers, backend, initializers, callbacks
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
import pickle

# %% [markdown]
# Initialize random seed to make random function call consistent and result is reproducible

# %%
np.random.seed(123)
tf.compat.v1.random.set_random_seed(123)

# %% [markdown]
# ## Getting Data
# First let's download CIFAR10 dataset from Universeity of Toronto

# %%
_URL = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'

zip_dir = tf.keras.utils.get_file('cifar10.zip', origin=_URL, extract=True, cache_dir='/content/')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %% [markdown]
# The downloaded zip files contain 5 training datasets, 1 test datasets, and a meta file describe data
#
# <pre style="font-size: 10.0pt; font-family: Arial; line-height: 2; letter-spacing: 1.0pt;" >
# <b>datasets</b>
# |__ <b>cifar-10-batches-py</b>
#     |______ <b>batches.meta</b>
#     |______ <b>data_batch_1</b>
#     |______ <b>data_batch_2</b>
#     |______ <b>data_batch_3</b>
#     |______ <b>data_batch_4</b>
#     |______ <b>data_batch_5</b>
#     |______ <b>readme.html</b>
#     |______ <b>test_batch</b>
# </pre>
#
# As described by [Alex Krizhevsky](https://en.wikipedia.org/wiki/AlexNet), each of these files is a Python "pickled" object produced with cPickle. We can use the provided function below to load the data into python dictionary object

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin')
    return dict

# %% [markdown]
# ## Understanding data
# Let's take a look at the content of the 1st data batch using function above

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cifar-10-batches-py')
data_1 = unpickle(os.path.join(base_dir,'data_batch_1'))

print('Content of  data file: ', list(data_1))
print('Length of input data: ', len(data_1['data'][0]))
print('Sample data: ', (data_1['data'][0]))
print('Length of output data: ', len(data_1['labels'][0:1]))


meta = unpickle(os.path.join(base_dir,'batches.meta'))
print('Content of meta: ', meta)
# Out:
# Content of  data file:  ['batch_label', 'labels', 'data', 'filenames']
# Length of input data:  3072
# Sample data:  [ 59  43  50 ... 140  84  72]
# Length of output data:  1
# Content of meta:  {'num_cases_per_batch': 10000, 'label_names': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'], 'num_vis': 3072}

# %% [markdown]
# ## Processing Data
#
# Now we will create a function to concatenate 6 batches of data into train data, train label, test data, and test label.

# %%
def load_datasets(path):
  train_x = []
  train_y = []
  test_x = []
  test_y = []
  classes = []
  for file in os.listdir(base_dir):
    if file.startswith('data_batch'):
      data = unpickle(os.path.join(base_dir,file))
      train_x.extend(data['data'])
      train_y.extend(data['labels'])
    if file == 'test_batch' :
      data = unpickle(os.path.join(base_dir,file))
      test_x = data['data']
      test_y = data['labels']
    if file == 'batches.meta':
      data = unpickle(os.path.join(base_dir,file))
      classes.extend(data['label_names'])
  
  train_x = np.array(train_x)
  train_y = np.array(train_y)
  test_x = np.array(test_x)
  test_y = np.array(test_y)

  return train_x, train_y, test_x, test_y, classes

# %%
train_x, train_y, test_x, test_y, classes = load_datasets(base_dir)

print(train_x.shape)
print(test_x.shape)
print(classes)
# Out:
# (50000, 3072)
# (10000, 3072)
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
a=dict(zip(*np.unique(train_y, return_counts=True)))
print("Training Data Distribution")
for k in a:
  print(classes[k], '\t:', a[k])
# Out:
# Training Data Distribution
# airplane 	: 5000
# automobile 	: 5000
# bird 	: 5000
# cat 	: 5000
# deer 	: 5000
# dog 	: 5000
# frog 	: 5000
# horse 	: 5000
# ship 	: 5000
# truck 	: 5000

# %%
a=dict(zip(*np.unique(test_y, return_counts=True)))
print("Testing Data Distribution")
for k in a:
  print(classes[k], '\t:', a[k])
# Out:
# Testing Data Distribution
# airplane 	: 1000
# automobile 	: 1000
# bird 	: 1000
# cat 	: 1000
# deer 	: 1000
# dog 	: 1000
# frog 	: 1000
# horse 	: 1000
# ship 	: 1000
# truck 	: 1000

# %% [markdown]
# CIFAR10 contains object classification from 32 x 32 color image. It would be better to display image and corrsponding label. However, the image information have flatten into 3072 array. To display the data as image, we will have to reverse the flatten into 32 x 32 x3 array.
#
# Now define 2 utility functions for purpose above:
#
#
# *   ```reverse_flat``` : to reverse the flatten 3072 features back to 32 x 32 RGB information
# *   ```display_image```: display image using the input of 32 x 32 RGB image information

# %%
def reverse_flat(datasets):
  img_data = []
  for data in (datasets):
#    r = datasets[i][0:1024].reshape(32,32)
#    g = datasets[i][1024:2048].reshape(32,32)
#    b = datasets[i][2048:].reshape(32,32)
    r = data[0:1024].reshape(32,32)
    g = data[1024:2048].reshape(32,32)
    b = data[2048:].reshape(32,32)
    img_data.append(np.dstack([r,g,b]))
  img_data = np.array(img_data)
  return img_data

def display_image(images, labels, preds=[]):

  m = images.shape[0]
  col = 8
  row = math.ceil(m / col) 
  if len(preds) == 0:
    preds = np.zeros(m)-1
  fig, axes = plt.subplots(row, col,squeeze=True, figsize=(12 ,12))
  fig.subplots_adjust(wspace=1, hspace=1)
  axes = axes.flatten()
  for img, ax, label, pred in zip(images, axes, labels, preds):
    ax.imshow(img)
    ax.set_title(classes[label])
    if pred > -1:
      if label == pred:
        ax.set_xlabel(classes[pred],color='green')
      else:
        ax.set_xlabel(classes[pred],color='red')
    #ax.axis('off')
    ax.set_xticks([])
    ax.set_yticks([])
  
  while m <  (col * row):
    fig.delaxes(axes[m])
    m=m+1
  plt.tight_layout()
  plt.show()

# %% [markdown]
# Take some images from the 50000 random samples

# %%
samples = [random.randrange(1, 50000, 1) for _ in range(50)]
display_image(reverse_flat(train_x[samples]), train_y[samples])
#display_image(reverse_flat(train_x[0:15]), train_y[0:15])
#display_image(reverse_flat(train_x[0:1]), train_y[0:1])

# %% [markdown]
# ## Rescaling Data
#
# To treat all pixels which train under same weights, learning rate for contributes more evenly to the loss, input data have to rescale pixel value from  [0,255] -> [0,1]

# %%
scaler = MinMaxScaler()
train_x_scaled = scaler.fit_transform(train_x.astype(np.float64))
test_x_scaled = scaler.fit_transform(test_x.astype(np.float64))

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Consideration for Parameter

# %% [markdown]
# ### Number of layers and neuron units
#
# To get started without random guessing on numbers of layers and neurons for the network, the models are design based on the rules of thumb suggested by [Jeff Heaton](https://www.heatonresearch.com/2017/06/01/hidden-layers.html) as below.

# %% [markdown]
# #### <u>Layers</u>
# <table alight='left'>
# <tr>
# <td><b>Num Hidden Layers</b></td><td><b>Result</b></td>
# </tr
# <tr>
# <td>none</td> <td>Only capable of representing linear separable functions or decisions.
# </td></tr><tr><td>
# 1</td><td>	Can approximate any function that contains a continuous mapping from one finite space to another.
# </td></tr><tr><td>
# 2</td><td>Can represent an arbitrary decision boundary to arbitrary accuracy with rational activation functions and can approximate any smooth mapping to any accuracy.
# </td></tr><tr><td>
# >2</td><td>	Additional layers can learn complex representations (sort of automatic feature engineering) for layer layers.
# </td></tr><tr>
# </table>

# %% [markdown]
# #### <u>Neuron units</u>
#
# * The number of hidden neurons should be between the size of the input layer and the size of the output layer.
# * The number of hidden neurons should be 2/3 the size of the input layer, plus the size of the output layer.
# * The number of hidden neurons should be less than twice the size of the input layer.

# %% [markdown]
# ### Activation Functions

# %% [markdown]
# #### Hidden Layer
#
# <b>ReLU</b> can avoids and rectifies vanishing gradient problem. Beside, ReLU is also less expensive in term of computation compare to other non-linear activation function. It is good option for hidden layers in most of the neural networks.

# %% [markdown]
# #### Output Layer
#
#
# <b>Softmax</b> which allows comparison and thus supports multiple classes classification would be use for the 10 classes classifiction problem

# %% [markdown]
# ### Initialization of weights
#
# Zero weight initialize would make learning learning next layer become linear or same for all iteration. The best practice would be initialize weights by random values. By default, **Keras** will use ```Xavier Uniform Initalizer``` for weights. After some study [3], we found that ```Xavier Uniform Initializer``` work well for ```tanh``` activation. Since we use ```ReLU``` activation, ```HE Uniform Initalizer``` would be better option

# %%
init_w = initializers.he_uniform(seed=1234)

# %% [markdown]
# ### Optimization algorithms
#
# Stochastic Gradient Descent with Momentum

# %%
sgd = optimizers.SGD(learning_rate=0.01, momentum=0.7, nesterov=True, name ='SGD')

# %% [markdown]
# ### Epoch and Batch Size
#
# Epoch represent number of times the complete dataset is passthrough the training. Since Gradient Descent is an iterative process, updating weights with one epoch is not suffient. Large number of epoch would tend to overfitting but it help avoid local minimal. Overfitting issue can be resolve by various regularization techniques.

# %% [markdown]
# Batch size represent total number of training examples present in a single batch. If the batch size is 1, the training will be stochastic batch training which will update the weights for every example the model train. If the batch size is equal to total number of training examples, it would be a batch traiing which only update weights after entire dataset is scan through once. The best approach would be using mini batch which combine all the pros from two approaches above. Recommended batch size for mini batch approach would be a number that cab fit into memory. e.g. 32,64, 128, and etc.

# %%
epoch = 60
batch_size = 128

# %% [markdown]
# ### Checkpoint
#
# Checkpoint is one of the function to safekeep the best train model over the long training process. For this assignment, we choose to save the trained model which give the highest validation accuracy as the best model. The best model will use for evaluation and prediction on test dataset. Code snippet below is use to create ```Keras ModelCheckpoint```.

# %%
if not os.path.exists('/content/SavedModel/'):
  os.makedirs('/content/SavedModel/')
def get_mc(path):
  
  mc = callbacks.ModelCheckpoint(path, monitor='val_accuracy', mode='max', save_best_only=True)
  
  return mc

# %% [markdown]
# Before start buiding neural network model, define the function below to visualize learning loss and accuracy

# %%
def plot_history(history, eval_acc=None):

  print('Training accuracy: %.3f' % (history.history['accuracy'][-1] * 100))
  print('Validation accuracy: %.3f' % (history.history['val_accuracy'][-1] * 100))
  if eval_acc:
    print('Testing accuracy: %.3f' % (eval_acc * 100))
  print()
  fig, (p1, p2) = plt.subplots(1, 2, figsize=(15,5))
  # Plot training & validation accuracy values
  p1.plot(history.history['accuracy'])
  p1.plot(history.history['val_accuracy'])
  p1.set_title('Model accuracy')
  p1.set_ylabel('Accuracy')
  p1.set_xlabel('Epoch')
  p1.legend(['Train', 'Test'], loc='upper left')

  # Plot training & validation loss values
  p2.plot(history.history['loss'])
  p2.plot(history.history['val_loss'])
  p2.set_title('Model loss')
  p2.set_ylabel('Loss')
  p2.set_xlabel('Epoch')
  p2.legend(['Train', 'Test'], loc='upper right')
  plt.show()

# %% [markdown]
# ## Model 1A - Shallow Network with small number of neurons
#
# We start with a relative swallow and small neural networks with just 32 neurons.

# %% [markdown]
# ### Build

# %%
model_1A = tf.keras.models.Sequential(name='FNN-1A', layers=[
    Dense(32, name='FNN-1A-H1', activation = 'relu', kernel_initializer=init_w,  input_shape= (3072,)),    
    #Dense(32, name='fnn1-hidden_layer1', activation = 'relu', kernel_initializer=init_w),
    Dense(10, name='FNN-1A-Output',activation = 'softmax')
])

model_1A.summary()

plot_model(model_1A)
cp_1A = '/content/SavedModel/best_1A_model.h5'
mc = callbacks.ModelCheckpoint(cp_1A,monitor='val_loss', mode='min',verbose=0, save_best_only=True)
# Out:
# Model: "FNN-1A"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FNN-1A-H1 (Dense)            (None, 32)                98336
# _________________________________________________________________
# FNN-1A-Output (Dense)        (None, 10)                330
# =================================================================
# Total params: 98,666
# Trainable params: 98,666
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model_1A.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_1A = model_1A.fit(train_x_scaled, train_y,validation_split=0.2, shuffle=True,batch_size=batch_size,epochs=epoch ,verbose=1, callbacks=[mc])
model_1A_best = models.load_model(cp_1A)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 3s 86us/sample - loss: 2.0013 - accuracy: 0.2710 - val_loss: 1.9139 - val_accuracy: 0.3191
# Epoch 2/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.8222 - accuracy: 0.3544 - val_loss: 1.8434 - val_accuracy: 0.3378
# Epoch 3/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.7515 - accuracy: 0.3817 - val_loss: 1.7756 - val_accuracy: 0.3755
# Epoch 4/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.7061 - accuracy: 0.3964 - val_loss: 1.7792 - val_accuracy: 0.3646
# Epoch 5/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.6714 - accuracy: 0.4074 - val_loss: 1.7182 - val_accuracy: 0.4007
# Epoch 6/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.6433 - accuracy: 0.4198 - val_loss: 1.6874 - val_accuracy: 0.4131
# Epoch 7/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.6199 - accuracy: 0.4287 - val_loss: 1.6539 - val_accuracy: 0.4136
# Epoch 8/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.6026 - accuracy: 0.4345 - val_loss: 1.6909 - val_accuracy: 0.4075
# Epoch 9/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.5861 - accuracy: 0.4408 - val_loss: 1.6501 - val_accuracy: 0.4195
# Epoch 10/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.5708 - accuracy: 0.4444 - val_loss: 1.6765 - val_accuracy: 0.4103
# Epoch 11/60
# 40000/40000 [==============================] - 2s 48us/sample - loss: 1.5592 - accuracy: 0.4505 - val_loss: 1.6490 - val_accuracy: 0.4220
# Epoch 12/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.5423 - accuracy: 0.4564 - val_loss: 1.6029 - val_accuracy: 0.4348
# Epoch 13/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.5339 - accuracy: 0.4597 - val_loss: 1.6107 - val_accuracy: 0.4259
# Epoch 14/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.5274 - accuracy: 0.4640 - val_loss: 1.6108 - val_accuracy: 0.4329
# Epoch 15/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.5146 - accuracy: 0.4674 - val_loss: 1.7061 - val_accuracy: 0.4085
# Epoch 16/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.5055 - accuracy: 0.4684 - val_loss: 1.5860 - val_accuracy: 0.4442
# Epoch 17/60
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.4963 - accuracy: 0.4730 - val_loss: 1.5696 - val_accuracy: 0.4481
# Epoch 18/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4900 - accuracy: 0.4761 - val_loss: 1.6136 - val_accuracy: 0.4262
# Epoch 19/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.4817 - accuracy: 0.4783 - val_loss: 1.6253 - val_accuracy: 0.4291
# Epoch 20/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4738 - accuracy: 0.4805 - val_loss: 1.6503 - val_accuracy: 0.4166
# Epoch 21/60
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.4686 - accuracy: 0.4816 - val_loss: 1.5701 - val_accuracy: 0.4417
# Epoch 22/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4604 - accuracy: 0.4868 - val_loss: 1.6056 - val_accuracy: 0.4327
# Epoch 23/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4587 - accuracy: 0.4870 - val_loss: 1.7987 - val_accuracy: 0.3912
# Epoch 24/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4504 - accuracy: 0.4880 - val_loss: 1.5763 - val_accuracy: 0.4468
# Epoch 25/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.4444 - accuracy: 0.4914 - val_loss: 1.5350 - val_accuracy: 0.4566
# Epoch 26/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.4404 - accuracy: 0.4926 - val_loss: 1.5468 - val_accuracy: 0.4582
# Epoch 27/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.4362 - accuracy: 0.4952 - val_loss: 1.5784 - val_accuracy: 0.4438
# Epoch 28/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4280 - accuracy: 0.4966 - val_loss: 1.6280 - val_accuracy: 0.4238
# Epoch 29/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4251 - accuracy: 0.4954 - val_loss: 1.5397 - val_accuracy: 0.4573
# Epoch 30/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.4196 - accuracy: 0.4997 - val_loss: 1.5604 - val_accuracy: 0.4556
# Epoch 31/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.4149 - accuracy: 0.5003 - val_loss: 1.5342 - val_accuracy: 0.4629
# Epoch 32/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.4098 - accuracy: 0.5056 - val_loss: 1.5590 - val_accuracy: 0.4472
# Epoch 33/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.4024 - accuracy: 0.5047 - val_loss: 1.5514 - val_accuracy: 0.4508
# Epoch 34/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.4011 - accuracy: 0.5071 - val_loss: 1.5498 - val_accuracy: 0.4597
# Epoch 35/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.3958 - accuracy: 0.5068 - val_loss: 1.5565 - val_accuracy: 0.4527
# Epoch 36/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3933 - accuracy: 0.5087 - val_loss: 1.5732 - val_accuracy: 0.4468
# Epoch 37/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3854 - accuracy: 0.5112 - val_loss: 1.5449 - val_accuracy: 0.4595
# Epoch 38/60
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3846 - accuracy: 0.5117 - val_loss: 1.6422 - val_accuracy: 0.4243
# Epoch 39/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.3835 - accuracy: 0.5124 - val_loss: 1.6608 - val_accuracy: 0.4291
# Epoch 40/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3794 - accuracy: 0.5120 - val_loss: 1.5395 - val_accuracy: 0.4602
# Epoch 41/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3725 - accuracy: 0.5170 - val_loss: 1.6071 - val_accuracy: 0.4546
# Epoch 42/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3732 - accuracy: 0.5187 - val_loss: 1.6388 - val_accuracy: 0.4376
# Epoch 43/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.3658 - accuracy: 0.5186 - val_loss: 1.5476 - val_accuracy: 0.4607
# Epoch 44/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3649 - accuracy: 0.5191 - val_loss: 1.5575 - val_accuracy: 0.4554
# Epoch 45/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.3597 - accuracy: 0.5181 - val_loss: 1.5320 - val_accuracy: 0.4601
# Epoch 46/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3597 - accuracy: 0.5206 - val_loss: 1.5057 - val_accuracy: 0.4758
# Epoch 47/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3526 - accuracy: 0.5227 - val_loss: 1.5549 - val_accuracy: 0.4684
# Epoch 48/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3485 - accuracy: 0.5234 - val_loss: 1.5276 - val_accuracy: 0.4676
# Epoch 49/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3481 - accuracy: 0.5234 - val_loss: 1.5404 - val_accuracy: 0.4635
# Epoch 50/60
# 40000/40000 [==============================] - 2s 47us/sample - loss: 1.3477 - accuracy: 0.5257 - val_loss: 1.5344 - val_accuracy: 0.4633
# Epoch 51/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3446 - accuracy: 0.5275 - val_loss: 1.6644 - val_accuracy: 0.4351
# Epoch 52/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3396 - accuracy: 0.5266 - val_loss: 1.5874 - val_accuracy: 0.4458
# Epoch 53/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3348 - accuracy: 0.5294 - val_loss: 1.5229 - val_accuracy: 0.4684
# Epoch 54/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3360 - accuracy: 0.5296 - val_loss: 1.5557 - val_accuracy: 0.4607
# Epoch 55/60
# 40000/40000 [==============================] - 2s 45us/sample - loss: 1.3300 - accuracy: 0.5333 - val_loss: 1.6332 - val_accuracy: 0.4412
# Epoch 56/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3260 - accuracy: 0.5320 - val_loss: 1.5702 - val_accuracy: 0.4666
# Epoch 57/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3247 - accuracy: 0.5321 - val_loss: 1.5546 - val_accuracy: 0.4666
# Epoch 58/60
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3240 - accuracy: 0.5326 - val_loss: 1.5306 - val_accuracy: 0.4682
# Epoch 59/60
# 40000/40000 [==============================] - 2s 46us/sample - loss: 1.3201 - accuracy: 0.5318 - val_loss: 1.5963 - val_accuracy: 0.4421
# Epoch 60/60
# 40000/40000 [==============================] - 2s 44us/sample - loss: 1.3222 - accuracy: 0.5336 - val_loss: 1.5942 - val_accuracy: 0.4556

# %% [markdown]
# ### Evaluation

# %%
_,acc = model_1A_best.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_1A, acc)
# Out:
# Training accuracy: 53.357
# Validation accuracy: 45.560
# Testing accuracy: 48.120

# %% [markdown]
# The simple shallow network offer an approximately 48% accuracy for classifying CIFAR-10 data sets. As seen above, the model start diverge after 20 epochs.

# %% [markdown]
# ## Model 1B - Shallow Network with larger number of neurons
#
# Next we would check if increase number of neurons would help improve on performance.

# %% [markdown]
# ### Build

# %%
model_1B = tf.keras.models.Sequential(name='FNN-1B', layers=[
    #Dense(2054, name='FNN-1B-H1', activation = 'relu', kernel_initializer=init_w,  input_shape= (3072,)),    
    Dense(6144, name='FNN-1B-H1', activation = 'relu', kernel_initializer=init_w,  input_shape= (3072,)),    
    Dense(10, name='FNN-1B-Output',activation = 'softmax')
])

model_1B.summary()

cp_1B = '/content/SavedModel/best_1B_model.h5'
mc = callbacks.ModelCheckpoint(cp_1B,monitor='val_loss', mode='min',verbose=0, save_best_only=True)
plot_model(model_1B)
# Out:
# Model: "FNN-1B"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FNN-1B-H1 (Dense)            (None, 6144)              18880512
# _________________________________________________________________
# FNN-1B-Output (Dense)        (None, 10)                61450
# =================================================================
# Total params: 18,941,962
# Trainable params: 18,941,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model_1B.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_1B = model_1B.fit(train_x_scaled, train_y,validation_split=0.2, shuffle=True,batch_size=batch_size,epochs=epoch ,verbose=1, callbacks=[mc])
model_1B_best = models.load_model(cp_1B)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 5s 129us/sample - loss: 1.9040 - accuracy: 0.3621 - val_loss: 1.7713 - val_accuracy: 0.3692
# Epoch 2/60
# 40000/40000 [==============================] - 5s 121us/sample - loss: 1.6312 - accuracy: 0.4303 - val_loss: 1.6757 - val_accuracy: 0.4020
# Epoch 3/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.5546 - accuracy: 0.4594 - val_loss: 1.6023 - val_accuracy: 0.4425
# Epoch 4/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.5021 - accuracy: 0.4788 - val_loss: 1.6064 - val_accuracy: 0.4224
# Epoch 5/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.4565 - accuracy: 0.4949 - val_loss: 1.5653 - val_accuracy: 0.4634
# Epoch 6/60
# 40000/40000 [==============================] - 5s 121us/sample - loss: 1.4200 - accuracy: 0.5069 - val_loss: 1.5389 - val_accuracy: 0.4631
# Epoch 7/60
# 40000/40000 [==============================] - 5s 121us/sample - loss: 1.3855 - accuracy: 0.5239 - val_loss: 1.5093 - val_accuracy: 0.4765
# Epoch 8/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.3564 - accuracy: 0.5307 - val_loss: 1.5445 - val_accuracy: 0.4612
# Epoch 9/60
# 40000/40000 [==============================] - 5s 120us/sample - loss: 1.3302 - accuracy: 0.5417 - val_loss: 1.4698 - val_accuracy: 0.4906
# Epoch 10/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 1.3031 - accuracy: 0.5523 - val_loss: 1.4778 - val_accuracy: 0.4868
# Epoch 11/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.2779 - accuracy: 0.5608 - val_loss: 1.4947 - val_accuracy: 0.4747
# Epoch 12/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.2508 - accuracy: 0.5707 - val_loss: 1.4243 - val_accuracy: 0.5052
# Epoch 13/60
# 40000/40000 [==============================] - 5s 123us/sample - loss: 1.2320 - accuracy: 0.5770 - val_loss: 1.4224 - val_accuracy: 0.5040
# Epoch 14/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 1.2104 - accuracy: 0.5874 - val_loss: 1.4430 - val_accuracy: 0.5006
# Epoch 15/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 1.1881 - accuracy: 0.5957 - val_loss: 1.4333 - val_accuracy: 0.4981
# Epoch 16/60
# 40000/40000 [==============================] - 5s 120us/sample - loss: 1.1664 - accuracy: 0.6038 - val_loss: 1.4008 - val_accuracy: 0.5140
# Epoch 17/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1448 - accuracy: 0.6101 - val_loss: 1.4432 - val_accuracy: 0.5015
# Epoch 18/60
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.1314 - accuracy: 0.6127 - val_loss: 1.5026 - val_accuracy: 0.4809
# Epoch 19/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 1.1093 - accuracy: 0.6219 - val_loss: 1.5157 - val_accuracy: 0.4730
# Epoch 20/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.0911 - accuracy: 0.6289 - val_loss: 1.4170 - val_accuracy: 0.5121
# Epoch 21/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.0717 - accuracy: 0.6359 - val_loss: 1.4872 - val_accuracy: 0.4847
# Epoch 22/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 1.0547 - accuracy: 0.6430 - val_loss: 1.4617 - val_accuracy: 0.4930
# Epoch 23/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 1.0407 - accuracy: 0.6478 - val_loss: 1.4669 - val_accuracy: 0.4924
# Epoch 24/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 1.0183 - accuracy: 0.6558 - val_loss: 1.4539 - val_accuracy: 0.4962
# Epoch 25/60
# 40000/40000 [==============================] - 5s 119us/sample - loss: 1.0034 - accuracy: 0.6616 - val_loss: 1.3902 - val_accuracy: 0.5170
# Epoch 26/60
# 40000/40000 [==============================] - 5s 122us/sample - loss: 0.9865 - accuracy: 0.6684 - val_loss: 1.3488 - val_accuracy: 0.5349
# Epoch 27/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.9744 - accuracy: 0.6713 - val_loss: 1.3940 - val_accuracy: 0.5212
# Epoch 28/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.9510 - accuracy: 0.6816 - val_loss: 1.5492 - val_accuracy: 0.4810
# Epoch 29/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.9400 - accuracy: 0.6856 - val_loss: 1.4275 - val_accuracy: 0.5078
# Epoch 30/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.9237 - accuracy: 0.6915 - val_loss: 1.4000 - val_accuracy: 0.5165
# Epoch 31/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.9088 - accuracy: 0.6960 - val_loss: 1.4124 - val_accuracy: 0.5151
# Epoch 32/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.8921 - accuracy: 0.7040 - val_loss: 1.4426 - val_accuracy: 0.5013
# Epoch 33/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.8761 - accuracy: 0.7075 - val_loss: 1.3894 - val_accuracy: 0.5228
# Epoch 34/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.8669 - accuracy: 0.7115 - val_loss: 1.3603 - val_accuracy: 0.5328
# Epoch 35/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.8465 - accuracy: 0.7199 - val_loss: 1.4157 - val_accuracy: 0.5175
# Epoch 36/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.8303 - accuracy: 0.7262 - val_loss: 1.4407 - val_accuracy: 0.5126
# Epoch 37/60
# 40000/40000 [==============================] - 5s 119us/sample - loss: 0.8148 - accuracy: 0.7311 - val_loss: 1.3470 - val_accuracy: 0.5407
# Epoch 38/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.8029 - accuracy: 0.7358 - val_loss: 1.4566 - val_accuracy: 0.5067
# Epoch 39/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.7885 - accuracy: 0.7433 - val_loss: 1.5399 - val_accuracy: 0.4835
# Epoch 40/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.7677 - accuracy: 0.7482 - val_loss: 1.5126 - val_accuracy: 0.4963
# Epoch 41/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.7601 - accuracy: 0.7523 - val_loss: 1.4651 - val_accuracy: 0.5166
# Epoch 42/60
# 40000/40000 [==============================] - 5s 114us/sample - loss: 0.7416 - accuracy: 0.7598 - val_loss: 1.6332 - val_accuracy: 0.4755
# Epoch 43/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.7369 - accuracy: 0.7586 - val_loss: 1.4796 - val_accuracy: 0.5105
# Epoch 44/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.7177 - accuracy: 0.7674 - val_loss: 1.5122 - val_accuracy: 0.5055
# Epoch 45/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.7091 - accuracy: 0.7700 - val_loss: 1.5424 - val_accuracy: 0.4902
# Epoch 46/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.6965 - accuracy: 0.7742 - val_loss: 1.4612 - val_accuracy: 0.5184
# Epoch 47/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.6789 - accuracy: 0.7803 - val_loss: 1.4578 - val_accuracy: 0.5266
# Epoch 48/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.6679 - accuracy: 0.7851 - val_loss: 1.4519 - val_accuracy: 0.5245
# Epoch 49/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.6529 - accuracy: 0.7914 - val_loss: 1.4634 - val_accuracy: 0.5196
# Epoch 50/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.6394 - accuracy: 0.7964 - val_loss: 1.3914 - val_accuracy: 0.5440
# Epoch 51/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.6300 - accuracy: 0.7987 - val_loss: 1.5474 - val_accuracy: 0.5091
# Epoch 52/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.6108 - accuracy: 0.8068 - val_loss: 1.4811 - val_accuracy: 0.5196
# Epoch 53/60
# 40000/40000 [==============================] - 4s 109us/sample - loss: 0.6072 - accuracy: 0.8087 - val_loss: 1.4270 - val_accuracy: 0.5330
# Epoch 54/60
# 40000/40000 [==============================] - 4s 110us/sample - loss: 0.5942 - accuracy: 0.8153 - val_loss: 1.5558 - val_accuracy: 0.5116
# Epoch 55/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.5751 - accuracy: 0.8214 - val_loss: 1.7630 - val_accuracy: 0.4803
# Epoch 56/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.5659 - accuracy: 0.8249 - val_loss: 1.5801 - val_accuracy: 0.5128
# Epoch 57/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.5526 - accuracy: 0.8307 - val_loss: 1.5410 - val_accuracy: 0.5212
# Epoch 58/60
# 40000/40000 [==============================] - 5s 113us/sample - loss: 0.5402 - accuracy: 0.8317 - val_loss: 1.5711 - val_accuracy: 0.5142
# Epoch 59/60
# 40000/40000 [==============================] - 4s 111us/sample - loss: 0.5248 - accuracy: 0.8404 - val_loss: 1.4879 - val_accuracy: 0.5192
# Epoch 60/60
# 40000/40000 [==============================] - 4s 112us/sample - loss: 0.5278 - accuracy: 0.8384 - val_loss: 1.4730 - val_accuracy: 0.5319
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Evaluate

# %%
_,acc = model_1B_best.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_1B, acc)
# Out:
# Training accuracy: 83.842
# Validation accuracy: 53.190
# Testing accuracy: 53.540

# %% [markdown]
# Increased too 6024 neurons gave great performance boost to training and testing accuracy. The model started with smaller loss although it reach similar number of validation loss with model 1A after 60 epochs. However, model 1B become overfitting after 10 epochs which earlier than model 1A.
#
# Training accuracy is increase to 84% and testing accuracy increased to 53%
#
# Hence we can conclude that increase number of neurons can improve performance, but also likely cause the model to overfitting sooner.
# We will address the overfitting issue in regularization.

# %% [markdown]
# ## Model 2 - 3 Layers Neural Network
#
# Let's check if increase number of layers do help on performance.

# %% [markdown]
# ### Build

# %%
model_2 = tf.keras.models.Sequential(name='FNN-2', layers= [
    Dense(6144, activation = 'relu', kernel_initializer=init_w, input_shape= (3072,), name='FNN-2-H1'),    
    Dense(3072, activation = 'relu', kernel_initializer=init_w,name='FNN-2-H2'),
    Dense(10, activation = 'softmax', name='FNN-1A-O1')
])

model_2.summary()
cp_2 = '/content/SavedModel/best_2_model.h5'
mc = callbacks.ModelCheckpoint(cp_2,monitor='val_loss', mode='min',verbose=0, save_best_only=True)

plot_model(model_2)
# Out:
# Model: "FNN-2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FNN-2-H1 (Dense)             (None, 6144)              18880512
# _________________________________________________________________
# FNN-2-H2 (Dense)             (None, 3072)              18877440
# _________________________________________________________________
# FNN-1A-O1 (Dense)            (None, 10)                30730
# =================================================================
# Total params: 37,788,682
# Trainable params: 37,788,682
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model_2.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])



history_2 = model_2.fit(train_x_scaled, train_y,epochs=epoch,validation_split=0.2,shuffle=True, batch_size=batch_size, verbose=1, callbacks=[mc])
model_2_best = models.load_model(cp_2)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 10s 250us/sample - loss: 1.8736 - accuracy: 0.3607 - val_loss: 1.7670 - val_accuracy: 0.3721
# Epoch 2/60
# 40000/40000 [==============================] - 10s 239us/sample - loss: 1.6044 - accuracy: 0.4354 - val_loss: 1.6871 - val_accuracy: 0.4027
# Epoch 3/60
# 40000/40000 [==============================] - 10s 238us/sample - loss: 1.5135 - accuracy: 0.4694 - val_loss: 1.5553 - val_accuracy: 0.4523
# Epoch 4/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 1.4483 - accuracy: 0.4942 - val_loss: 1.5867 - val_accuracy: 0.4292
# Epoch 5/60
# 40000/40000 [==============================] - 9s 236us/sample - loss: 1.3901 - accuracy: 0.5153 - val_loss: 1.4831 - val_accuracy: 0.4868
# Epoch 6/60
# 40000/40000 [==============================] - 8s 212us/sample - loss: 1.3402 - accuracy: 0.5321 - val_loss: 1.4896 - val_accuracy: 0.4724
# Epoch 7/60
# 40000/40000 [==============================] - 9s 237us/sample - loss: 1.2948 - accuracy: 0.5531 - val_loss: 1.4650 - val_accuracy: 0.4839
# Epoch 8/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 1.2529 - accuracy: 0.5649 - val_loss: 1.5150 - val_accuracy: 0.4739
# Epoch 9/60
# 40000/40000 [==============================] - 10s 240us/sample - loss: 1.2166 - accuracy: 0.5799 - val_loss: 1.4080 - val_accuracy: 0.5105
# Epoch 10/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 1.1746 - accuracy: 0.5969 - val_loss: 1.4255 - val_accuracy: 0.5059
# Epoch 11/60
# 40000/40000 [==============================] - 9s 217us/sample - loss: 1.1388 - accuracy: 0.6113 - val_loss: 1.4577 - val_accuracy: 0.4891
# Epoch 12/60
# 40000/40000 [==============================] - 10s 244us/sample - loss: 1.0967 - accuracy: 0.6245 - val_loss: 1.4073 - val_accuracy: 0.5048
# Epoch 13/60
# 40000/40000 [==============================] - 10s 242us/sample - loss: 1.0674 - accuracy: 0.6338 - val_loss: 1.3930 - val_accuracy: 0.5149
# Epoch 14/60
# 40000/40000 [==============================] - 9s 219us/sample - loss: 1.0340 - accuracy: 0.6484 - val_loss: 1.4012 - val_accuracy: 0.5163
# Epoch 15/60
# 40000/40000 [==============================] - 10s 238us/sample - loss: 0.9966 - accuracy: 0.6629 - val_loss: 1.3854 - val_accuracy: 0.5188
# Epoch 16/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.9589 - accuracy: 0.6772 - val_loss: 1.3943 - val_accuracy: 0.5207
# Epoch 17/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.9253 - accuracy: 0.6895 - val_loss: 1.4525 - val_accuracy: 0.5163
# Epoch 18/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.8985 - accuracy: 0.7000 - val_loss: 1.4582 - val_accuracy: 0.5030
# Epoch 19/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.8594 - accuracy: 0.7146 - val_loss: 1.5261 - val_accuracy: 0.4917
# Epoch 20/60
# 40000/40000 [==============================] - 10s 241us/sample - loss: 0.8285 - accuracy: 0.7272 - val_loss: 1.3739 - val_accuracy: 0.5289
# Epoch 21/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.7935 - accuracy: 0.7393 - val_loss: 1.4833 - val_accuracy: 0.5031
# Epoch 22/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.7645 - accuracy: 0.7522 - val_loss: 1.4352 - val_accuracy: 0.5143
# Epoch 23/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.7337 - accuracy: 0.7613 - val_loss: 1.5059 - val_accuracy: 0.5039
# Epoch 24/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.6968 - accuracy: 0.7761 - val_loss: 1.5756 - val_accuracy: 0.4993
# Epoch 25/60
# 40000/40000 [==============================] - 9s 234us/sample - loss: 0.6692 - accuracy: 0.7854 - val_loss: 1.3629 - val_accuracy: 0.5373
# Epoch 26/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.6369 - accuracy: 0.7981 - val_loss: 1.3702 - val_accuracy: 0.5389
# Epoch 27/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.6087 - accuracy: 0.8078 - val_loss: 1.4116 - val_accuracy: 0.5343
# Epoch 28/60
# 40000/40000 [==============================] - 8s 212us/sample - loss: 0.5738 - accuracy: 0.8233 - val_loss: 1.5225 - val_accuracy: 0.5111
# Epoch 29/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.5511 - accuracy: 0.8319 - val_loss: 1.4481 - val_accuracy: 0.5345
# Epoch 30/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.5226 - accuracy: 0.8432 - val_loss: 1.4110 - val_accuracy: 0.5321
# Epoch 31/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.4965 - accuracy: 0.8504 - val_loss: 1.5055 - val_accuracy: 0.5225
# Epoch 32/60
# 40000/40000 [==============================] - 8s 212us/sample - loss: 0.4651 - accuracy: 0.8625 - val_loss: 1.4724 - val_accuracy: 0.5284
# Epoch 33/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.4397 - accuracy: 0.8759 - val_loss: 1.4676 - val_accuracy: 0.5326
# Epoch 34/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.4174 - accuracy: 0.8820 - val_loss: 1.4187 - val_accuracy: 0.5408
# Epoch 35/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.3901 - accuracy: 0.8899 - val_loss: 1.5167 - val_accuracy: 0.5264
# Epoch 36/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.3674 - accuracy: 0.8995 - val_loss: 1.4549 - val_accuracy: 0.5456
# Epoch 37/60
# 40000/40000 [==============================] - 8s 212us/sample - loss: 0.3441 - accuracy: 0.9069 - val_loss: 1.4618 - val_accuracy: 0.5497
# Epoch 38/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.3202 - accuracy: 0.9174 - val_loss: 1.5440 - val_accuracy: 0.5327
# Epoch 39/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.3006 - accuracy: 0.9233 - val_loss: 1.8780 - val_accuracy: 0.4919
# Epoch 40/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.2800 - accuracy: 0.9309 - val_loss: 1.5412 - val_accuracy: 0.5369
# Epoch 41/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.2623 - accuracy: 0.9369 - val_loss: 1.5185 - val_accuracy: 0.5418
# Epoch 42/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.2376 - accuracy: 0.9456 - val_loss: 1.5565 - val_accuracy: 0.5430
# Epoch 43/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.2279 - accuracy: 0.9489 - val_loss: 1.5639 - val_accuracy: 0.5378
# Epoch 44/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.2095 - accuracy: 0.9556 - val_loss: 1.4781 - val_accuracy: 0.5598
# Epoch 45/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.1932 - accuracy: 0.9589 - val_loss: 1.5944 - val_accuracy: 0.5336
# Epoch 46/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.1781 - accuracy: 0.9651 - val_loss: 1.6916 - val_accuracy: 0.5302
# Epoch 47/60
# 40000/40000 [==============================] - 9s 217us/sample - loss: 0.1704 - accuracy: 0.9654 - val_loss: 1.5588 - val_accuracy: 0.5551
# Epoch 48/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.1519 - accuracy: 0.9733 - val_loss: 1.5344 - val_accuracy: 0.5609
# Epoch 49/60
# 40000/40000 [==============================] - 9s 219us/sample - loss: 0.1393 - accuracy: 0.9764 - val_loss: 1.5855 - val_accuracy: 0.5483
# Epoch 50/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.1318 - accuracy: 0.9775 - val_loss: 1.5946 - val_accuracy: 0.5509
# Epoch 51/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.1203 - accuracy: 0.9806 - val_loss: 1.5985 - val_accuracy: 0.5606
# Epoch 52/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.1087 - accuracy: 0.9846 - val_loss: 1.6080 - val_accuracy: 0.5507
# Epoch 53/60
# 40000/40000 [==============================] - 9s 215us/sample - loss: 0.1081 - accuracy: 0.9840 - val_loss: 1.7216 - val_accuracy: 0.5516
# Epoch 54/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.0989 - accuracy: 0.9860 - val_loss: 1.6723 - val_accuracy: 0.5569
# Epoch 55/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.0900 - accuracy: 0.9883 - val_loss: 1.6320 - val_accuracy: 0.5655
# Epoch 56/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.0796 - accuracy: 0.9903 - val_loss: 1.6332 - val_accuracy: 0.5622
# Epoch 57/60
# 40000/40000 [==============================] - 9s 213us/sample - loss: 0.0726 - accuracy: 0.9922 - val_loss: 1.6499 - val_accuracy: 0.5629
# Epoch 58/60
# 40000/40000 [==============================] - 9s 218us/sample - loss: 0.0682 - accuracy: 0.9932 - val_loss: 1.7902 - val_accuracy: 0.5465
# Epoch 59/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 0.0661 - accuracy: 0.9930 - val_loss: 1.6422 - val_accuracy: 0.5596
# Epoch 60/60
# 40000/40000 [==============================] - 9s 214us/sample - loss: 0.0588 - accuracy: 0.9948 - val_loss: 1.6860 - val_accuracy: 0.5579
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Evaluation

# %%
_,acc = model_2_best.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_2, acc)
# Out:
# Training accuracy: 99.480
# Validation accuracy: 55.790
# Testing accuracy: 54.490

# %% [markdown]
# With the additional layer, training performance is increased to 99% and have clear signed of overfitting on train dataset. The accuracy for validation and test dataset remain hovering around 56% and 54%. The model become overfitting after 10 epochs.
# The increase in validation loss show that overfitting model will reduce performance of remaining iteration.

# %% [markdown]
# ## Model 3 Deep Neural Network
#
# In the next cell, we will try to construct a deeper network with thinner layers. The total number of parameters would be lesser than Model 2, hence it shall delay the overfitting effect and allow the model to train longer.

# %% [markdown]
# ### Build

# %%
model_3 = tf.keras.models.Sequential(name='FNN-3', layers= [
    Dense(2054, activation='relu', kernel_initializer=init_w,  input_shape= (3072,), name='FNN-3-H1'),
    Dense(1024, activation='relu', kernel_initializer=init_w, name='FNN-3-H2'),
    Dense(1024, activation='relu', kernel_initializer=init_w, name='FNN-3-H3'),
    Dense(1024, activation='relu', kernel_initializer=init_w, name='FNN-3-H4'),
    Dense(1024, activation='relu', kernel_initializer=init_w, name='FNN-3-H5'),
    Dense(924, activation='relu', kernel_initializer=init_w, name='FNN-3-H6'),
    Dense(924, activation='relu', kernel_initializer=init_w, name='FNN-3-H7'),
    Dense(768, activation='relu', kernel_initializer=init_w, name='FNN-3-H8'),
    Dense(768, activation='relu', kernel_initializer=init_w, name='FNN-3-H9'),
    Dense(768, activation='relu', kernel_initializer=init_w, name='FNN-3-H10'),
    Dense(768, activation='relu', kernel_initializer=init_w, name='FNN-3-H11'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H12'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H13'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H14'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H15'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H16'),
    Dense(512, activation='relu', kernel_initializer=init_w, name='FNN-3-H17'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H18'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H19'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H20'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H21'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H22'),
    Dense(256, activation='relu', kernel_initializer=init_w, name='FNN-3-H23'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H24'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H25'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H26'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H27'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H28'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H29'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H30'),
    Dense(128, activation='relu', kernel_initializer=init_w, name='FNN-3-H31'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H32'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H33'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H34'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H35'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H36'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H37'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H38'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H39'),
    Dense(64, activation='relu', kernel_initializer=init_w, name='FNN-3-H40'),
    Dense(10, activation = 'softmax', name='FNN-3-O1')
])

model_3.summary()
cp_3 = '/content/SavedModel/best_3_model.h5'
mc = get_mc(cp_3)

plot_model(model_3)
# Out:
# Model: "FNN-3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FNN-3-H1 (Dense)             (None, 2054)              6311942
# _________________________________________________________________
# FNN-3-H2 (Dense)             (None, 1024)              2104320
# _________________________________________________________________
# FNN-3-H3 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# FNN-3-H4 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# FNN-3-H5 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# FNN-3-H6 (Dense)             (None, 924)               947100
# _________________________________________________________________
# FNN-3-H7 (Dense)             (None, 924)               854700
# _________________________________________________________________
# FNN-3-H8 (Dense)             (None, 768)               710400
# _________________________________________________________________
# FNN-3-H9 (Dense)             (None, 768)               590592
# _________________________________________________________________
# FNN-3-H10 (Dense)            (None, 768)               590592
# _________________________________________________________________
# FNN-3-H11 (Dense)            (None, 768)               590592
# _________________________________________________________________
# FNN-3-H12 (Dense)            (None, 512)               393728
# _________________________________________________________________
# FNN-3-H13 (Dense)            (None, 512)               262656
# _________________________________________________________________
# FNN-3-H14 (Dense)            (None, 512)               262656
# _________________________________________________________________
# FNN-3-H15 (Dense)            (None, 512)               262656
# _________________________________________________________________
# FNN-3-H16 (Dense)            (None, 512)               262656
# _________________________________________________________________
# FNN-3-H17 (Dense)            (None, 512)               262656
# _________________________________________________________________
# FNN-3-H18 (Dense)            (None, 256)               131328
# _________________________________________________________________
# FNN-3-H19 (Dense)            (None, 256)               65792
# _________________________________________________________________
# FNN-3-H20 (Dense)            (None, 256)               65792
# _________________________________________________________________
# FNN-3-H21 (Dense)            (None, 256)               65792
# _________________________________________________________________
# FNN-3-H22 (Dense)            (None, 256)               65792
# _________________________________________________________________
# FNN-3-H23 (Dense)            (None, 256)               65792
# _________________________________________________________________
# FNN-3-H24 (Dense)            (None, 128)               32896
# _________________________________________________________________
# FNN-3-H25 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H26 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H27 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H28 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H29 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H30 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H31 (Dense)            (None, 128)               16512
# _________________________________________________________________
# FNN-3-H32 (Dense)            (None, 64)                8256
# _________________________________________________________________
# FNN-3-H33 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H34 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H35 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H36 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H37 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H38 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H39 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-H40 (Dense)            (None, 64)                4160
# _________________________________________________________________
# FNN-3-O1 (Dense)             (None, 10)                650
# =================================================================
# Total params: 18,207,000
# Trainable params: 18,207,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model_3.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])



history_3 = model_3.fit(train_x_scaled, train_y,epochs=epoch,shuffle=True,validation_split=0.2, batch_size=batch_size, verbose=1, callbacks=[mc])
model_3_best = models.load_model(cp_3)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 12s 289us/sample - loss: 2.1870 - accuracy: 0.1490 - val_loss: 2.2190 - val_accuracy: 0.1955
# Epoch 2/60
# 40000/40000 [==============================] - 9s 226us/sample - loss: 2.0829 - accuracy: 0.1898 - val_loss: 2.0135 - val_accuracy: 0.2249
# Epoch 3/60
# 40000/40000 [==============================] - 9s 231us/sample - loss: 1.9644 - accuracy: 0.2371 - val_loss: 1.8815 - val_accuracy: 0.2747
# Epoch 4/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 1.8799 - accuracy: 0.2799 - val_loss: 2.0078 - val_accuracy: 0.2550
# Epoch 5/60
# 40000/40000 [==============================] - 9s 228us/sample - loss: 1.8439 - accuracy: 0.3035 - val_loss: 1.8300 - val_accuracy: 0.3203
# Epoch 6/60
# 40000/40000 [==============================] - 9s 225us/sample - loss: 1.7841 - accuracy: 0.3298 - val_loss: 1.7944 - val_accuracy: 0.3319
# Epoch 7/60
# 40000/40000 [==============================] - 9s 229us/sample - loss: 1.7751 - accuracy: 0.3393 - val_loss: 1.7618 - val_accuracy: 0.3501
# Epoch 8/60
# 40000/40000 [==============================] - 8s 204us/sample - loss: 1.7306 - accuracy: 0.3561 - val_loss: 1.8265 - val_accuracy: 0.3240
# Epoch 9/60
# 40000/40000 [==============================] - 8s 204us/sample - loss: 1.6837 - accuracy: 0.3729 - val_loss: 1.7824 - val_accuracy: 0.3368
# Epoch 10/60
# 40000/40000 [==============================] - 9s 231us/sample - loss: 1.6586 - accuracy: 0.3902 - val_loss: 1.6796 - val_accuracy: 0.3806
# Epoch 11/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.6297 - accuracy: 0.3980 - val_loss: 1.7917 - val_accuracy: 0.3549
# Epoch 12/60
# 40000/40000 [==============================] - 9s 227us/sample - loss: 1.6012 - accuracy: 0.4144 - val_loss: 1.6389 - val_accuracy: 0.4069
# Epoch 13/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.5817 - accuracy: 0.4270 - val_loss: 1.7132 - val_accuracy: 0.3912
# Epoch 14/60
# 40000/40000 [==============================] - 9s 231us/sample - loss: 1.5632 - accuracy: 0.4364 - val_loss: 1.6861 - val_accuracy: 0.4097
# Epoch 15/60
# 40000/40000 [==============================] - 9s 227us/sample - loss: 1.5397 - accuracy: 0.4475 - val_loss: 1.6026 - val_accuracy: 0.4245
# Epoch 16/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 1.5139 - accuracy: 0.4593 - val_loss: 1.7526 - val_accuracy: 0.3814
# Epoch 17/60
# 40000/40000 [==============================] - 9s 233us/sample - loss: 1.5004 - accuracy: 0.4622 - val_loss: 1.5913 - val_accuracy: 0.4289
# Epoch 18/60
# 40000/40000 [==============================] - 9s 228us/sample - loss: 1.4844 - accuracy: 0.4658 - val_loss: 1.5732 - val_accuracy: 0.4421
# Epoch 19/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.4613 - accuracy: 0.4763 - val_loss: 1.6920 - val_accuracy: 0.4107
# Epoch 20/60
# 40000/40000 [==============================] - 8s 200us/sample - loss: 1.4306 - accuracy: 0.4873 - val_loss: 1.6675 - val_accuracy: 0.4176
# Epoch 21/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.4366 - accuracy: 0.4908 - val_loss: 1.6772 - val_accuracy: 0.4158
# Epoch 22/60
# 40000/40000 [==============================] - 9s 228us/sample - loss: 1.4122 - accuracy: 0.4978 - val_loss: 1.6287 - val_accuracy: 0.4430
# Epoch 23/60
# 40000/40000 [==============================] - 9s 226us/sample - loss: 1.3819 - accuracy: 0.5076 - val_loss: 1.5445 - val_accuracy: 0.4608
# Epoch 24/60
# 40000/40000 [==============================] - 8s 206us/sample - loss: 1.3573 - accuracy: 0.5175 - val_loss: 1.8971 - val_accuracy: 0.3863
# Epoch 25/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 1.3541 - accuracy: 0.5173 - val_loss: 1.5441 - val_accuracy: 0.4539
# Epoch 26/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.3259 - accuracy: 0.5324 - val_loss: 1.6339 - val_accuracy: 0.4587
# Epoch 27/60
# 40000/40000 [==============================] - 9s 228us/sample - loss: 1.3145 - accuracy: 0.5360 - val_loss: 1.5156 - val_accuracy: 0.4758
# Epoch 28/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.2904 - accuracy: 0.5413 - val_loss: 1.5828 - val_accuracy: 0.4565
# Epoch 29/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.2671 - accuracy: 0.5509 - val_loss: 1.6208 - val_accuracy: 0.4618
# Epoch 30/60
# 40000/40000 [==============================] - 9s 230us/sample - loss: 1.2472 - accuracy: 0.5596 - val_loss: 1.5314 - val_accuracy: 0.4774
# Epoch 31/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 1.2420 - accuracy: 0.5627 - val_loss: 1.6073 - val_accuracy: 0.4604
# Epoch 32/60
# 40000/40000 [==============================] - 9s 228us/sample - loss: 1.2173 - accuracy: 0.5710 - val_loss: 1.5463 - val_accuracy: 0.4824
# Epoch 33/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.2020 - accuracy: 0.5766 - val_loss: 1.7284 - val_accuracy: 0.4434
# Epoch 34/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.1706 - accuracy: 0.5876 - val_loss: 1.6566 - val_accuracy: 0.4587
# Epoch 35/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.1475 - accuracy: 0.5961 - val_loss: 1.6642 - val_accuracy: 0.4605
# Epoch 36/60
# 40000/40000 [==============================] - 8s 200us/sample - loss: 1.1354 - accuracy: 0.5978 - val_loss: 1.6033 - val_accuracy: 0.4747
# Epoch 37/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.1226 - accuracy: 0.6044 - val_loss: 1.5670 - val_accuracy: 0.4767
# Epoch 38/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.0882 - accuracy: 0.6185 - val_loss: 1.5699 - val_accuracy: 0.4733
# Epoch 39/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 1.0781 - accuracy: 0.6203 - val_loss: 1.6053 - val_accuracy: 0.4570
# Epoch 40/60
# 40000/40000 [==============================] - 9s 229us/sample - loss: 1.0518 - accuracy: 0.6306 - val_loss: 1.5748 - val_accuracy: 0.4898
# Epoch 41/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.0408 - accuracy: 0.6337 - val_loss: 1.5886 - val_accuracy: 0.4733
# Epoch 42/60
# 40000/40000 [==============================] - 8s 200us/sample - loss: 1.0305 - accuracy: 0.6397 - val_loss: 1.6222 - val_accuracy: 0.4744
# Epoch 43/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 1.0025 - accuracy: 0.6491 - val_loss: 1.7806 - val_accuracy: 0.4660
# Epoch 44/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.9822 - accuracy: 0.6583 - val_loss: 1.6213 - val_accuracy: 0.4883
# Epoch 45/60
# 40000/40000 [==============================] - 8s 200us/sample - loss: 0.9567 - accuracy: 0.6671 - val_loss: 1.7117 - val_accuracy: 0.4827
# Epoch 46/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.9341 - accuracy: 0.6719 - val_loss: 1.6233 - val_accuracy: 0.4883
# Epoch 47/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 0.9157 - accuracy: 0.6810 - val_loss: 1.8269 - val_accuracy: 0.4885
# Epoch 48/60
# 40000/40000 [==============================] - 9s 230us/sample - loss: 0.8922 - accuracy: 0.6914 - val_loss: 1.7397 - val_accuracy: 0.4951
# Epoch 49/60
# 40000/40000 [==============================] - 9s 231us/sample - loss: 0.8621 - accuracy: 0.7003 - val_loss: 1.5646 - val_accuracy: 0.5054
# Epoch 50/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.8525 - accuracy: 0.7033 - val_loss: 1.6910 - val_accuracy: 0.4918
# Epoch 51/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 0.8589 - accuracy: 0.7042 - val_loss: 1.6786 - val_accuracy: 0.5050
# Epoch 52/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 0.8148 - accuracy: 0.7196 - val_loss: 1.7493 - val_accuracy: 0.4889
# Epoch 53/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 0.7863 - accuracy: 0.7285 - val_loss: 1.6392 - val_accuracy: 0.5044
# Epoch 54/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 0.7739 - accuracy: 0.7343 - val_loss: 1.7653 - val_accuracy: 0.4974
# Epoch 55/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.7471 - accuracy: 0.7443 - val_loss: 1.8270 - val_accuracy: 0.4719
# Epoch 56/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.7507 - accuracy: 0.7435 - val_loss: 1.8085 - val_accuracy: 0.4927
# Epoch 57/60
# 40000/40000 [==============================] - 8s 202us/sample - loss: 0.7076 - accuracy: 0.7562 - val_loss: 1.8287 - val_accuracy: 0.4875
# Epoch 58/60
# 40000/40000 [==============================] - 8s 203us/sample - loss: 0.7007 - accuracy: 0.7635 - val_loss: 1.7499 - val_accuracy: 0.4887
# Epoch 59/60
# 40000/40000 [==============================] - 8s 204us/sample - loss: 0.6730 - accuracy: 0.7706 - val_loss: 1.9082 - val_accuracy: 0.4882
# Epoch 60/60
# 40000/40000 [==============================] - 8s 201us/sample - loss: 0.6563 - accuracy: 0.7765 - val_loss: 1.9662 - val_accuracy: 0.4835
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ### Evaluation

# %%
_,acc = model_3_best.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_3, acc)
# Out:
# Training accuracy: 77.650
# Validation accuracy: 48.350
# Testing accuracy: 51.240

# %% [markdown]
# The training accuracy graph is smoother compare to other models. Accuracy is increase slower in each iteration.
# Although thinner network can avoid early overfitting, but there is increase in training error for the overall model. After 40 epochs, the validation loss begin to diverge from training loss, show that the model isn't able to improve further due to overfitting.

# %% [markdown]
# # Regularization

# %% [markdown]
# In the following cells, we will be performing regularization.
#
# The objective of regularization is to reduce the effect of overfitting. Overfitting is observed when the training accuracy is much higher than validation accuracy. When training accuracy is too high, that means that the model is not robust when predicting new data, or in other words it could not generalize.
#
# There are various regularization techniques. We will be using L1 L2 regularization and Dropout to regulate the shallow and deep models respectively.

# %% [markdown]
# ##L1 L2 Regularization
#
# In this cell we will set the L1 and L2 regularizer to 0.0001. This figure is much smaller than expected. These parameters were determined through trying from a range of 0.5 to 0.00001.
#
# When the L1 and L2 values are closer to 0.00001, the model will overfit as per no regularization.
#
# And when the values approaches 0.5, the accuracies start oscillating.

# %%
l1_l2 = regularizers.l1_l2(l1=0.000085,l2=0.000085)

# %% [markdown]
# ###Model 1 (L1 L2)
# Defining and train the model with L1 and L2 regularizers.

# %%
model_1_reg = tf.keras.models.Sequential(name='FNN-1-Reg', layers=[
    Dense(3072, activation='relu',kernel_initializer=init_w,bias_initializer=init_w,input_shape= (3072,), kernel_regularizer=l1_l2, bias_regularizer=l1_l2), 
    Dense(1024, activation='relu',kernel_initializer=init_w,bias_initializer=init_w, kernel_regularizer=l1_l2, bias_regularizer=l1_l2),   
    Dense(10, activation = 'softmax')
])

model_1_reg.summary()
model_1_reg.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_1_reg = model_1_reg.fit(train_x_scaled, train_y,validation_split=0.2, batch_size=batch_size,shuffle=True,epochs=100 ,verbose=1)
# Out:
# Model: "FNN-1-Reg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              3146752
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 12,597,258
# Trainable params: 12,597,258
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 7s 176us/sample - loss: 25.6928 - accuracy: 0.3468 - val_loss: 25.1350 - val_accuracy: 0.3608
# Epoch 2/100
# 40000/40000 [==============================] - 6s 157us/sample - loss: 24.4896 - accuracy: 0.4193 - val_loss: 24.0695 - val_accuracy: 0.3884
# Epoch 3/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 23.4280 - accuracy: 0.4476 - val_loss: 22.9804 - val_accuracy: 0.4315
# Epoch 4/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 22.4164 - accuracy: 0.4687 - val_loss: 22.0561 - val_accuracy: 0.4147
# Epoch 5/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 21.4361 - accuracy: 0.4856 - val_loss: 21.0375 - val_accuracy: 0.4720
# Epoch 6/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 20.4882 - accuracy: 0.4965 - val_loss: 20.1331 - val_accuracy: 0.4622
# Epoch 7/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 19.5714 - accuracy: 0.5089 - val_loss: 19.2168 - val_accuracy: 0.4765
# Epoch 8/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 18.6785 - accuracy: 0.5185 - val_loss: 18.4224 - val_accuracy: 0.4620
# Epoch 9/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 17.8151 - accuracy: 0.5256 - val_loss: 17.4920 - val_accuracy: 0.4933
# Epoch 10/100
# 40000/40000 [==============================] - 6s 157us/sample - loss: 16.9726 - accuracy: 0.5336 - val_loss: 16.7260 - val_accuracy: 0.4755
# Epoch 11/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 16.1598 - accuracy: 0.5390 - val_loss: 15.9669 - val_accuracy: 0.4644
# Epoch 12/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 15.3649 - accuracy: 0.5470 - val_loss: 15.1117 - val_accuracy: 0.4947
# Epoch 13/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 14.6048 - accuracy: 0.5487 - val_loss: 14.3828 - val_accuracy: 0.4932
# Epoch 14/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 13.8688 - accuracy: 0.5520 - val_loss: 13.7140 - val_accuracy: 0.4837
# Epoch 15/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 13.1455 - accuracy: 0.5581 - val_loss: 13.0199 - val_accuracy: 0.4791
# Epoch 16/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 12.4536 - accuracy: 0.5626 - val_loss: 12.3117 - val_accuracy: 0.4867
# Epoch 17/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 11.7819 - accuracy: 0.5636 - val_loss: 11.6297 - val_accuracy: 0.5073
# Epoch 18/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 11.1408 - accuracy: 0.5637 - val_loss: 11.0979 - val_accuracy: 0.4620
# Epoch 19/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 10.5176 - accuracy: 0.5674 - val_loss: 10.4935 - val_accuracy: 0.4637
# Epoch 20/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 9.9184 - accuracy: 0.5696 - val_loss: 9.8618 - val_accuracy: 0.4796
# Epoch 21/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 9.3456 - accuracy: 0.5698 - val_loss: 9.2609 - val_accuracy: 0.4852
# Epoch 22/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 8.7972 - accuracy: 0.5683 - val_loss: 8.8450 - val_accuracy: 0.4493
# Epoch 23/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 8.2714 - accuracy: 0.5697 - val_loss: 8.3147 - val_accuracy: 0.4676
# Epoch 24/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 7.7629 - accuracy: 0.5674 - val_loss: 7.9015 - val_accuracy: 0.4472
# Epoch 25/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 7.2825 - accuracy: 0.5694 - val_loss: 7.2018 - val_accuracy: 0.5127
# Epoch 26/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 6.8225 - accuracy: 0.5709 - val_loss: 6.7380 - val_accuracy: 0.5205
# Epoch 27/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 6.3915 - accuracy: 0.5658 - val_loss: 6.3883 - val_accuracy: 0.4900
# Epoch 28/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 5.9723 - accuracy: 0.5669 - val_loss: 6.0593 - val_accuracy: 0.4560
# Epoch 29/100
# 40000/40000 [==============================] - 6s 157us/sample - loss: 5.5860 - accuracy: 0.5616 - val_loss: 5.6085 - val_accuracy: 0.4822
# Epoch 30/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 5.2212 - accuracy: 0.5604 - val_loss: 5.2422 - val_accuracy: 0.4876
# Epoch 31/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 4.8827 - accuracy: 0.5550 - val_loss: 4.8213 - val_accuracy: 0.5158
# Epoch 32/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 4.5506 - accuracy: 0.5560 - val_loss: 4.5563 - val_accuracy: 0.4856
# Epoch 33/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 4.2511 - accuracy: 0.5537 - val_loss: 4.2481 - val_accuracy: 0.5014
# Epoch 34/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 3.9863 - accuracy: 0.5457 - val_loss: 3.9476 - val_accuracy: 0.5121
# Epoch 35/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 3.7186 - accuracy: 0.5469 - val_loss: 3.7566 - val_accuracy: 0.4771
# Epoch 36/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 3.4877 - accuracy: 0.5422 - val_loss: 3.5980 - val_accuracy: 0.4491
# Epoch 37/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 3.2759 - accuracy: 0.5378 - val_loss: 3.2618 - val_accuracy: 0.5092
# Epoch 38/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 3.0832 - accuracy: 0.5329 - val_loss: 3.1463 - val_accuracy: 0.4588
# Epoch 39/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 2.9083 - accuracy: 0.5266 - val_loss: 3.1033 - val_accuracy: 0.4339
# Epoch 40/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 2.7477 - accuracy: 0.5272 - val_loss: 2.8672 - val_accuracy: 0.4495
# Epoch 41/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 2.6120 - accuracy: 0.5243 - val_loss: 2.7542 - val_accuracy: 0.4500
# Epoch 42/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 2.4803 - accuracy: 0.5239 - val_loss: 2.8792 - val_accuracy: 0.3730
# Epoch 43/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 2.3779 - accuracy: 0.5167 - val_loss: 2.4885 - val_accuracy: 0.4494
# Epoch 44/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 2.2764 - accuracy: 0.5139 - val_loss: 2.3002 - val_accuracy: 0.4945
# Epoch 45/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 2.1856 - accuracy: 0.5181 - val_loss: 2.2506 - val_accuracy: 0.4796
# Epoch 46/100
# 40000/40000 [==============================] - 6s 158us/sample - loss: 2.1162 - accuracy: 0.5167 - val_loss: 2.1585 - val_accuracy: 0.4882
# Epoch 47/100
# 40000/40000 [==============================] - 6s 157us/sample - loss: 2.0488 - accuracy: 0.5177 - val_loss: 2.1762 - val_accuracy: 0.4597
# Epoch 48/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.9994 - accuracy: 0.5151 - val_loss: 2.0408 - val_accuracy: 0.4940
# Epoch 49/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.9577 - accuracy: 0.5155 - val_loss: 2.0253 - val_accuracy: 0.4773
# Epoch 50/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.9190 - accuracy: 0.5184 - val_loss: 2.0492 - val_accuracy: 0.4581
# Epoch 51/100
# 40000/40000 [==============================] - 6s 158us/sample - loss: 1.8900 - accuracy: 0.5154 - val_loss: 2.0290 - val_accuracy: 0.4523
# Epoch 52/100
# 40000/40000 [==============================] - 6s 159us/sample - loss: 1.8447 - accuracy: 0.5223 - val_loss: 2.0940 - val_accuracy: 0.4374
# Epoch 53/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.8081 - accuracy: 0.5259 - val_loss: 1.8662 - val_accuracy: 0.4994
# Epoch 54/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.7814 - accuracy: 0.5264 - val_loss: 1.8628 - val_accuracy: 0.4846
# Epoch 55/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.7483 - accuracy: 0.5295 - val_loss: 1.9966 - val_accuracy: 0.4414
# Epoch 56/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.7240 - accuracy: 0.5319 - val_loss: 1.8216 - val_accuracy: 0.4965
# Epoch 57/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.7010 - accuracy: 0.5311 - val_loss: 1.8241 - val_accuracy: 0.4951
# Epoch 58/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.6754 - accuracy: 0.5372 - val_loss: 1.7704 - val_accuracy: 0.5014
# Epoch 59/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.6567 - accuracy: 0.5380 - val_loss: 1.7814 - val_accuracy: 0.4904
# Epoch 60/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.6449 - accuracy: 0.5374 - val_loss: 1.8062 - val_accuracy: 0.4810
# Epoch 61/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.6244 - accuracy: 0.5443 - val_loss: 1.7954 - val_accuracy: 0.4900
# Epoch 62/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.6088 - accuracy: 0.5467 - val_loss: 1.7212 - val_accuracy: 0.5046
# Epoch 63/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.5964 - accuracy: 0.5477 - val_loss: 1.8102 - val_accuracy: 0.4699
# Epoch 64/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.5829 - accuracy: 0.5488 - val_loss: 1.7958 - val_accuracy: 0.4732
# Epoch 65/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.5637 - accuracy: 0.5546 - val_loss: 1.7951 - val_accuracy: 0.4745
# Epoch 66/100
# 40000/40000 [==============================] - 6s 152us/sample - loss: 1.5557 - accuracy: 0.5562 - val_loss: 1.7343 - val_accuracy: 0.4819
# Epoch 67/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.5478 - accuracy: 0.5543 - val_loss: 1.7444 - val_accuracy: 0.4824
# Epoch 68/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.5329 - accuracy: 0.5583 - val_loss: 1.7515 - val_accuracy: 0.4710
# Epoch 69/100
# 40000/40000 [==============================] - 6s 152us/sample - loss: 1.5205 - accuracy: 0.5645 - val_loss: 1.6601 - val_accuracy: 0.5109
# Epoch 70/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.5148 - accuracy: 0.5641 - val_loss: 1.6791 - val_accuracy: 0.5095
# Epoch 71/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.5036 - accuracy: 0.5669 - val_loss: 1.6466 - val_accuracy: 0.5170
# Epoch 72/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4969 - accuracy: 0.5687 - val_loss: 1.7243 - val_accuracy: 0.4980
# Epoch 73/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4898 - accuracy: 0.5686 - val_loss: 1.6310 - val_accuracy: 0.5246
# Epoch 74/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4870 - accuracy: 0.5713 - val_loss: 1.7839 - val_accuracy: 0.4685
# Epoch 75/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4791 - accuracy: 0.5716 - val_loss: 1.6512 - val_accuracy: 0.5111
# Epoch 76/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4720 - accuracy: 0.5743 - val_loss: 1.8196 - val_accuracy: 0.4643
# Epoch 77/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4705 - accuracy: 0.5753 - val_loss: 1.6404 - val_accuracy: 0.5255
# Epoch 78/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.4527 - accuracy: 0.5797 - val_loss: 1.7150 - val_accuracy: 0.4920
# Epoch 79/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.4543 - accuracy: 0.5798 - val_loss: 1.6456 - val_accuracy: 0.5160
# Epoch 80/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4471 - accuracy: 0.5825 - val_loss: 1.7633 - val_accuracy: 0.4834
# Epoch 81/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4467 - accuracy: 0.5828 - val_loss: 1.7220 - val_accuracy: 0.4936
# Epoch 82/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4372 - accuracy: 0.5859 - val_loss: 1.6562 - val_accuracy: 0.5108
# Epoch 83/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4317 - accuracy: 0.5875 - val_loss: 1.6232 - val_accuracy: 0.5214
# Epoch 84/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4291 - accuracy: 0.5876 - val_loss: 1.6523 - val_accuracy: 0.5101
# Epoch 85/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.4212 - accuracy: 0.5899 - val_loss: 1.6809 - val_accuracy: 0.5093
# Epoch 86/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4214 - accuracy: 0.5919 - val_loss: 1.6686 - val_accuracy: 0.5077
# Epoch 87/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4141 - accuracy: 0.5940 - val_loss: 1.6176 - val_accuracy: 0.5269
# Epoch 88/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.4139 - accuracy: 0.5948 - val_loss: 1.6412 - val_accuracy: 0.5204
# Epoch 89/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4067 - accuracy: 0.5990 - val_loss: 1.7358 - val_accuracy: 0.4842
# Epoch 90/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.4039 - accuracy: 0.5986 - val_loss: 1.6225 - val_accuracy: 0.5275
# Epoch 91/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.4006 - accuracy: 0.6009 - val_loss: 1.7769 - val_accuracy: 0.4744
# Epoch 92/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.3990 - accuracy: 0.6019 - val_loss: 1.6051 - val_accuracy: 0.5255
# Epoch 93/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.3902 - accuracy: 0.6079 - val_loss: 1.7572 - val_accuracy: 0.4770
# Epoch 94/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.3921 - accuracy: 0.6048 - val_loss: 1.6611 - val_accuracy: 0.5206
# Epoch 95/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.3883 - accuracy: 0.6054 - val_loss: 1.6606 - val_accuracy: 0.5139
# Epoch 96/100
# 40000/40000 [==============================] - 6s 156us/sample - loss: 1.3848 - accuracy: 0.6063 - val_loss: 1.6635 - val_accuracy: 0.5050
# Epoch 97/100
# 40000/40000 [==============================] - 6s 155us/sample - loss: 1.3854 - accuracy: 0.6045 - val_loss: 1.7479 - val_accuracy: 0.4959
# Epoch 98/100
# 40000/40000 [==============================] - 6s 153us/sample - loss: 1.3863 - accuracy: 0.6097 - val_loss: 1.6099 - val_accuracy: 0.5324
# Epoch 99/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.3775 - accuracy: 0.6105 - val_loss: 1.6777 - val_accuracy: 0.5054
# Epoch 100/100
# 40000/40000 [==============================] - 6s 154us/sample - loss: 1.3745 - accuracy: 0.6119 - val_loss: 1.6145 - val_accuracy: 0.5262

# %% [markdown]
# ### Evaluation
# The following shows the accuracy and loss graphs for regulated shallow model.
#
# We observe that training and validation accuracies are close to each other as compared with unregularized model.
#
# As the training goes on in more epoch, the training accuracy does not increase too much over validation accuracy. This show that we curb overfitting to an extent.

# %%
_,acc = model_1_reg.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_1_reg, acc)
# Out:
# Training accuracy: 61.195
# Validation accuracy: 52.620
# Testing accuracy: 52.990

# %% [markdown]
# ###Oscillating Accuracies
#
# The following shows an example of how accuracies oscillates when the L1 and L2 values are larger. The model is seems to be generalized as the training and validation accuracies are close to each other.

# %%
l1_l2 = regularizers.l1_l2(l1=0.001,l2=0.001)

# %%
model_1_reg_osc = tf.keras.models.Sequential(name='FNN-1-Reg', layers=[
    Dense(3072, activation='relu',kernel_initializer=init_w,bias_initializer=init_w,input_shape= (3072,), kernel_regularizer=l1_l2, bias_regularizer=l1_l2), 
    Dense(2054, activation='relu',kernel_initializer=init_w,bias_initializer=init_w, kernel_regularizer=l1_l2, bias_regularizer=l1_l2),   
    Dense(10, activation = 'softmax')
])

model_1_reg_osc.summary()
model_1_reg_osc.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_1_reg_osc = model_1_reg_osc.fit(train_x_scaled, train_y,validation_split=0.2,shuffle=True, batch_size=batch_size,epochs=epoch ,verbose=1)
# Out:
# Model: "FNN-1-Reg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 3072)              9440256
# _________________________________________________________________
# dense_4 (Dense)              (None, 2054)              6311942
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                20550
# =================================================================
# Total params: 15,772,748
# Trainable params: 15,772,748
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 9s 216us/sample - loss: 279.6119 - accuracy: 0.3492 - val_loss: 204.7890 - val_accuracy: 0.3563
# Epoch 2/60
# 40000/40000 [==============================] - 7s 187us/sample - loss: 145.6121 - accuracy: 0.3883 - val_loss: 93.5618 - val_accuracy: 0.3346
# Epoch 3/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 56.5419 - accuracy: 0.3665 - val_loss: 26.6518 - val_accuracy: 0.3288
# Epoch 4/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 11.3687 - accuracy: 0.3028 - val_loss: 2.9621 - val_accuracy: 0.2117
# Epoch 5/60
# 40000/40000 [==============================] - 7s 187us/sample - loss: 2.3909 - accuracy: 0.2168 - val_loss: 2.2769 - val_accuracy: 0.2320
# Epoch 6/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.2157 - accuracy: 0.2609 - val_loss: 2.1941 - val_accuracy: 0.2681
# Epoch 7/60
# 40000/40000 [==============================] - 7s 187us/sample - loss: 2.1817 - accuracy: 0.2839 - val_loss: 2.1513 - val_accuracy: 0.3111
# Epoch 8/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1610 - accuracy: 0.2975 - val_loss: 2.1689 - val_accuracy: 0.3007
# Epoch 9/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1515 - accuracy: 0.3000 - val_loss: 2.1554 - val_accuracy: 0.2970
# Epoch 10/60
# 40000/40000 [==============================] - 7s 187us/sample - loss: 2.1459 - accuracy: 0.3026 - val_loss: 2.1757 - val_accuracy: 0.2827
# Epoch 11/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1406 - accuracy: 0.3035 - val_loss: 2.2668 - val_accuracy: 0.2731
# Epoch 12/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1386 - accuracy: 0.3056 - val_loss: 2.1537 - val_accuracy: 0.2985
# Epoch 13/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1328 - accuracy: 0.3072 - val_loss: 2.1796 - val_accuracy: 0.2810
# Epoch 14/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1319 - accuracy: 0.3084 - val_loss: 2.1463 - val_accuracy: 0.3041
# Epoch 15/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1302 - accuracy: 0.3067 - val_loss: 2.1953 - val_accuracy: 0.2740
# Epoch 16/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1289 - accuracy: 0.3085 - val_loss: 2.1153 - val_accuracy: 0.3113
# Epoch 17/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1226 - accuracy: 0.3079 - val_loss: 2.1375 - val_accuracy: 0.3152
# Epoch 18/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1232 - accuracy: 0.3085 - val_loss: 2.1898 - val_accuracy: 0.2806
# Epoch 19/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1226 - accuracy: 0.3073 - val_loss: 2.2001 - val_accuracy: 0.2800
# Epoch 20/60
# 40000/40000 [==============================] - 7s 187us/sample - loss: 2.1166 - accuracy: 0.3110 - val_loss: 2.1499 - val_accuracy: 0.3059
# Epoch 21/60
# 40000/40000 [==============================] - 7s 184us/sample - loss: 2.1202 - accuracy: 0.3135 - val_loss: 2.1133 - val_accuracy: 0.3142
# Epoch 22/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1192 - accuracy: 0.3124 - val_loss: 2.2328 - val_accuracy: 0.2752
# Epoch 23/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1180 - accuracy: 0.3103 - val_loss: 2.2665 - val_accuracy: 0.2585
# Epoch 24/60
# 40000/40000 [==============================] - 7s 184us/sample - loss: 2.1159 - accuracy: 0.3103 - val_loss: 2.1462 - val_accuracy: 0.2938
# Epoch 25/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1133 - accuracy: 0.3119 - val_loss: 2.1234 - val_accuracy: 0.3132
# Epoch 26/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1130 - accuracy: 0.3143 - val_loss: 2.1527 - val_accuracy: 0.2941
# Epoch 27/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1140 - accuracy: 0.3132 - val_loss: 2.1190 - val_accuracy: 0.3177
# Epoch 28/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1088 - accuracy: 0.3137 - val_loss: 2.1425 - val_accuracy: 0.2964
# Epoch 29/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1099 - accuracy: 0.3126 - val_loss: 2.1164 - val_accuracy: 0.3212
# Epoch 30/60
# 40000/40000 [==============================] - 7s 184us/sample - loss: 2.1082 - accuracy: 0.3145 - val_loss: 2.1285 - val_accuracy: 0.3167
# Epoch 31/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1073 - accuracy: 0.3171 - val_loss: 2.1121 - val_accuracy: 0.3130
# Epoch 32/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1068 - accuracy: 0.3177 - val_loss: 2.1598 - val_accuracy: 0.2962
# Epoch 33/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1045 - accuracy: 0.3169 - val_loss: 2.1243 - val_accuracy: 0.3124
# Epoch 34/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1031 - accuracy: 0.3162 - val_loss: 2.0959 - val_accuracy: 0.3247
# Epoch 35/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1034 - accuracy: 0.3193 - val_loss: 2.2079 - val_accuracy: 0.2810
# Epoch 36/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.1056 - accuracy: 0.3177 - val_loss: 2.1173 - val_accuracy: 0.3169
# Epoch 37/60
# 40000/40000 [==============================] - 8s 189us/sample - loss: 2.1006 - accuracy: 0.3203 - val_loss: 2.1074 - val_accuracy: 0.3177
# Epoch 38/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1026 - accuracy: 0.3211 - val_loss: 2.2211 - val_accuracy: 0.2725
# Epoch 39/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1022 - accuracy: 0.3209 - val_loss: 2.3366 - val_accuracy: 0.2601
# Epoch 40/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.1022 - accuracy: 0.3212 - val_loss: 2.1119 - val_accuracy: 0.3163
# Epoch 41/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0925 - accuracy: 0.3214 - val_loss: 2.1200 - val_accuracy: 0.3262
# Epoch 42/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0976 - accuracy: 0.3227 - val_loss: 2.1038 - val_accuracy: 0.3225
# Epoch 43/60
# 40000/40000 [==============================] - 8s 189us/sample - loss: 2.0965 - accuracy: 0.3207 - val_loss: 2.1269 - val_accuracy: 0.3107
# Epoch 44/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0994 - accuracy: 0.3224 - val_loss: 2.0857 - val_accuracy: 0.3272
# Epoch 45/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0951 - accuracy: 0.3232 - val_loss: 2.2040 - val_accuracy: 0.2825
# Epoch 46/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0959 - accuracy: 0.3232 - val_loss: 2.1010 - val_accuracy: 0.3138
# Epoch 47/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0914 - accuracy: 0.3255 - val_loss: 2.1741 - val_accuracy: 0.2964
# Epoch 48/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0955 - accuracy: 0.3235 - val_loss: 2.1321 - val_accuracy: 0.3152
# Epoch 49/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0931 - accuracy: 0.3224 - val_loss: 2.1159 - val_accuracy: 0.3158
# Epoch 50/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0982 - accuracy: 0.3210 - val_loss: 2.1362 - val_accuracy: 0.3097
# Epoch 51/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0944 - accuracy: 0.3250 - val_loss: 2.1745 - val_accuracy: 0.2958
# Epoch 52/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0886 - accuracy: 0.3265 - val_loss: 2.1720 - val_accuracy: 0.2971
# Epoch 53/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0898 - accuracy: 0.3248 - val_loss: 2.1044 - val_accuracy: 0.3200
# Epoch 54/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0953 - accuracy: 0.3243 - val_loss: 2.1324 - val_accuracy: 0.3112
# Epoch 55/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0912 - accuracy: 0.3258 - val_loss: 2.1527 - val_accuracy: 0.3032
# Epoch 56/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0909 - accuracy: 0.3290 - val_loss: 2.1294 - val_accuracy: 0.3069
# Epoch 57/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0906 - accuracy: 0.3255 - val_loss: 2.0808 - val_accuracy: 0.3307
# Epoch 58/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0882 - accuracy: 0.3285 - val_loss: 2.1971 - val_accuracy: 0.2917
# Epoch 59/60
# 40000/40000 [==============================] - 7s 185us/sample - loss: 2.0891 - accuracy: 0.3289 - val_loss: 2.1212 - val_accuracy: 0.3162
# Epoch 60/60
# 40000/40000 [==============================] - 7s 186us/sample - loss: 2.0888 - accuracy: 0.3250 - val_loss: 2.1480 - val_accuracy: 0.2997

# %%
_,acc = model_1_reg_osc.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_1_reg_osc, acc)
# Out:
# Training accuracy: 32.500
# Validation accuracy: 29.970
# Testing accuracy: 30.320

# %% [markdown]
# ##Dropout Regularization
#
# As deep learning networks have large number of layers and parameters, it becomes clear that applying L1 or L2 regularization might lead to slower training time due to requiring more calculations to be done. One way to regularize a deep neural network would be to use dropout.
#
# Dropout in neural networks meant that certain nodes within a layer would be "deactivated" based on the dropout rate for that layer. This would prevent the next layer of the network to correct problems of the previous layer [4]. Thus this would make the network more robust and learn more "generally", therefore acheiving the objective of reducing overfitting.

# %% [markdown]
# ### Model 3 (Dropout)
#
# Defining the model and using 30% dropout rate for most of the layers.
#
# These rates were determined through trials and testing. When assigned with higher dropout rates, we noticed that there is a decrease in overall accuracy of the model. Perhaps, in this situation, we would require more data to train the model to improve the accuracy.

# %%
model_3_reg = tf.keras.models.Sequential([
    Dense(2054, activation='relu', kernel_initializer=init_w,  input_shape= (3072,)),
    Dropout(rate=0.3),
    Dense(1376, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(32, activation='relu', kernel_initializer=init_w),
    Dense(1376, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(2054, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(10, activation = 'softmax')
])

model_3_reg.summary()

model_3_reg.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

cp_3_reg = '/content/SavedModel/best_3_model.h5'

mc = get_mc(cp_3_reg)

history_3_reg = model_3_reg.fit(train_x_scaled, train_y,epochs=100,validation_split=0.2,shuffle=True, batch_size=batch_size, callbacks=[mc])
model_3_reg_best = models.load_model(cp_3_reg)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 2054)              6311942
# _________________________________________________________________
# dropout (Dropout)            (None, 2054)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1376)              2827680
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1376)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                44064
# _________________________________________________________________
# dense_9 (Dense)              (None, 1376)              45408
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1376)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2054)              2828358
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2054)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                20550
# =================================================================
# Total params: 12,078,002
# Trainable params: 12,078,002
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 7s 177us/sample - loss: 2.2259 - accuracy: 0.1472 - val_loss: 2.0765 - val_accuracy: 0.2254
# Epoch 2/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 2.0420 - accuracy: 0.2212 - val_loss: 1.9693 - val_accuracy: 0.2508
# Epoch 3/100
# 40000/40000 [==============================] - 6s 159us/sample - loss: 1.9336 - accuracy: 0.2672 - val_loss: 1.8310 - val_accuracy: 0.3124
# Epoch 4/100
# 40000/40000 [==============================] - 7s 163us/sample - loss: 1.8735 - accuracy: 0.3050 - val_loss: 1.8085 - val_accuracy: 0.3354
# Epoch 5/100
# 40000/40000 [==============================] - 7s 165us/sample - loss: 1.8033 - accuracy: 0.3421 - val_loss: 1.7446 - val_accuracy: 0.3605
# Epoch 6/100
# 40000/40000 [==============================] - 6s 158us/sample - loss: 1.7507 - accuracy: 0.3588 - val_loss: 1.7036 - val_accuracy: 0.3730
# Epoch 7/100
# 40000/40000 [==============================] - 7s 164us/sample - loss: 1.7111 - accuracy: 0.3727 - val_loss: 1.6831 - val_accuracy: 0.3823
# Epoch 8/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.6852 - accuracy: 0.3831 - val_loss: 1.7209 - val_accuracy: 0.3766
# Epoch 9/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 1.6533 - accuracy: 0.3999 - val_loss: 1.6213 - val_accuracy: 0.4105
# Epoch 10/100
# 40000/40000 [==============================] - 7s 165us/sample - loss: 1.6268 - accuracy: 0.4071 - val_loss: 1.6038 - val_accuracy: 0.4230
# Epoch 11/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 1.6002 - accuracy: 0.4183 - val_loss: 1.5739 - val_accuracy: 0.4327
# Epoch 12/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 1.5769 - accuracy: 0.4277 - val_loss: 1.5566 - val_accuracy: 0.4420
# Epoch 13/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.5555 - accuracy: 0.4361 - val_loss: 1.5970 - val_accuracy: 0.4301
# Epoch 14/100
# 40000/40000 [==============================] - 6s 162us/sample - loss: 1.5338 - accuracy: 0.4434 - val_loss: 1.5476 - val_accuracy: 0.4510
# Epoch 15/100
# 40000/40000 [==============================] - 6s 162us/sample - loss: 1.5187 - accuracy: 0.4498 - val_loss: 1.5371 - val_accuracy: 0.4529
# Epoch 16/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 1.5005 - accuracy: 0.4565 - val_loss: 1.5156 - val_accuracy: 0.4563
# Epoch 17/100
# 40000/40000 [==============================] - 7s 166us/sample - loss: 1.4760 - accuracy: 0.4669 - val_loss: 1.4757 - val_accuracy: 0.4764
# Epoch 18/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.4632 - accuracy: 0.4708 - val_loss: 1.5027 - val_accuracy: 0.4534
# Epoch 19/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.4446 - accuracy: 0.4782 - val_loss: 1.4959 - val_accuracy: 0.4721
# Epoch 20/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.4317 - accuracy: 0.4843 - val_loss: 1.4898 - val_accuracy: 0.4671
# Epoch 21/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 1.4136 - accuracy: 0.4880 - val_loss: 1.4513 - val_accuracy: 0.4863
# Epoch 22/100
# 40000/40000 [==============================] - 5s 121us/sample - loss: 1.3990 - accuracy: 0.4942 - val_loss: 1.4789 - val_accuracy: 0.4660
# Epoch 23/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.3881 - accuracy: 0.4981 - val_loss: 1.4715 - val_accuracy: 0.4724
# Epoch 24/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.3757 - accuracy: 0.5003 - val_loss: 1.4699 - val_accuracy: 0.4783
# Epoch 25/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 1.3656 - accuracy: 0.5070 - val_loss: 1.4529 - val_accuracy: 0.4908
# Epoch 26/100
# 40000/40000 [==============================] - 5s 119us/sample - loss: 1.3488 - accuracy: 0.5142 - val_loss: 1.4471 - val_accuracy: 0.4883
# Epoch 27/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.3413 - accuracy: 0.5154 - val_loss: 1.4210 - val_accuracy: 0.4866
# Epoch 28/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.3273 - accuracy: 0.5236 - val_loss: 1.4578 - val_accuracy: 0.4761
# Epoch 29/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.3157 - accuracy: 0.5241 - val_loss: 1.4710 - val_accuracy: 0.4863
# Epoch 30/100
# 40000/40000 [==============================] - 6s 158us/sample - loss: 1.3010 - accuracy: 0.5314 - val_loss: 1.4255 - val_accuracy: 0.4946
# Epoch 31/100
# 40000/40000 [==============================] - 7s 168us/sample - loss: 1.2930 - accuracy: 0.5321 - val_loss: 1.4144 - val_accuracy: 0.5067
# Epoch 32/100
# 40000/40000 [==============================] - 5s 119us/sample - loss: 1.2847 - accuracy: 0.5382 - val_loss: 1.4569 - val_accuracy: 0.4914
# Epoch 33/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.2702 - accuracy: 0.5430 - val_loss: 1.4388 - val_accuracy: 0.4917
# Epoch 34/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.2599 - accuracy: 0.5452 - val_loss: 1.4626 - val_accuracy: 0.4867
# Epoch 35/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.2557 - accuracy: 0.5477 - val_loss: 1.4367 - val_accuracy: 0.4868
# Epoch 36/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.2360 - accuracy: 0.5497 - val_loss: 1.4029 - val_accuracy: 0.4998
# Epoch 37/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.2254 - accuracy: 0.5587 - val_loss: 1.4258 - val_accuracy: 0.5034
# Epoch 38/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.2179 - accuracy: 0.5608 - val_loss: 1.4076 - val_accuracy: 0.5016
# Epoch 39/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 1.2137 - accuracy: 0.5616 - val_loss: 1.4161 - val_accuracy: 0.5095
# Epoch 40/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1955 - accuracy: 0.5666 - val_loss: 1.4642 - val_accuracy: 0.4935
# Epoch 41/100
# 40000/40000 [==============================] - 6s 157us/sample - loss: 1.1881 - accuracy: 0.5717 - val_loss: 1.3706 - val_accuracy: 0.5174
# Epoch 42/100
# 40000/40000 [==============================] - 5s 121us/sample - loss: 1.1809 - accuracy: 0.5731 - val_loss: 1.3947 - val_accuracy: 0.5105
# Epoch 43/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1700 - accuracy: 0.5783 - val_loss: 1.4284 - val_accuracy: 0.5042
# Epoch 44/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.1527 - accuracy: 0.5823 - val_loss: 1.3872 - val_accuracy: 0.5130
# Epoch 45/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1523 - accuracy: 0.5843 - val_loss: 1.3853 - val_accuracy: 0.5116
# Epoch 46/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1344 - accuracy: 0.5917 - val_loss: 1.3924 - val_accuracy: 0.5099
# Epoch 47/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 1.1210 - accuracy: 0.5968 - val_loss: 1.3496 - val_accuracy: 0.5267
# Epoch 48/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.1190 - accuracy: 0.5982 - val_loss: 1.3894 - val_accuracy: 0.5197
# Epoch 49/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.1106 - accuracy: 0.6000 - val_loss: 1.3828 - val_accuracy: 0.5202
# Epoch 50/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.1023 - accuracy: 0.6022 - val_loss: 1.3839 - val_accuracy: 0.5173
# Epoch 51/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.0928 - accuracy: 0.6057 - val_loss: 1.4274 - val_accuracy: 0.5013
# Epoch 52/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.0788 - accuracy: 0.6088 - val_loss: 1.3951 - val_accuracy: 0.5190
# Epoch 53/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.0762 - accuracy: 0.6117 - val_loss: 1.4240 - val_accuracy: 0.5158
# Epoch 54/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.0624 - accuracy: 0.6187 - val_loss: 1.3755 - val_accuracy: 0.5248
# Epoch 55/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.0560 - accuracy: 0.6199 - val_loss: 1.3879 - val_accuracy: 0.5183
# Epoch 56/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.0455 - accuracy: 0.6254 - val_loss: 1.3739 - val_accuracy: 0.5261
# Epoch 57/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.0351 - accuracy: 0.6263 - val_loss: 1.3751 - val_accuracy: 0.5202
# Epoch 58/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 1.0312 - accuracy: 0.6301 - val_loss: 1.3970 - val_accuracy: 0.5280
# Epoch 59/100
# 40000/40000 [==============================] - 5s 119us/sample - loss: 1.0244 - accuracy: 0.6298 - val_loss: 1.3932 - val_accuracy: 0.5231
# Epoch 60/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.0090 - accuracy: 0.6363 - val_loss: 1.4847 - val_accuracy: 0.4916
# Epoch 61/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.9999 - accuracy: 0.6397 - val_loss: 1.3880 - val_accuracy: 0.5218
# Epoch 62/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 0.9882 - accuracy: 0.6468 - val_loss: 1.3503 - val_accuracy: 0.5313
# Epoch 63/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.9846 - accuracy: 0.6437 - val_loss: 1.3935 - val_accuracy: 0.5238
# Epoch 64/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.9808 - accuracy: 0.6474 - val_loss: 1.3619 - val_accuracy: 0.5288
# Epoch 65/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.9679 - accuracy: 0.6509 - val_loss: 1.5041 - val_accuracy: 0.4923
# Epoch 66/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.9593 - accuracy: 0.6514 - val_loss: 1.3760 - val_accuracy: 0.5271
# Epoch 67/100
# 40000/40000 [==============================] - 6s 160us/sample - loss: 0.9516 - accuracy: 0.6596 - val_loss: 1.3618 - val_accuracy: 0.5354
# Epoch 68/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.9413 - accuracy: 0.6618 - val_loss: 1.3844 - val_accuracy: 0.5302
# Epoch 69/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.9382 - accuracy: 0.6596 - val_loss: 1.3884 - val_accuracy: 0.5241
# Epoch 70/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 0.9240 - accuracy: 0.6669 - val_loss: 1.4417 - val_accuracy: 0.5192
# Epoch 71/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 0.9165 - accuracy: 0.6710 - val_loss: 1.3859 - val_accuracy: 0.5315
# Epoch 72/100
# 40000/40000 [==============================] - 6s 161us/sample - loss: 0.9159 - accuracy: 0.6694 - val_loss: 1.3376 - val_accuracy: 0.5484
# Epoch 73/100
# 40000/40000 [==============================] - 5s 119us/sample - loss: 0.9027 - accuracy: 0.6761 - val_loss: 1.4051 - val_accuracy: 0.5188
# Epoch 74/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.8949 - accuracy: 0.6778 - val_loss: 1.4600 - val_accuracy: 0.5065
# Epoch 75/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.8913 - accuracy: 0.6779 - val_loss: 1.3992 - val_accuracy: 0.5271
# Epoch 76/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8815 - accuracy: 0.6846 - val_loss: 1.3899 - val_accuracy: 0.5335
# Epoch 77/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8676 - accuracy: 0.6890 - val_loss: 1.3692 - val_accuracy: 0.5353
# Epoch 78/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 0.8610 - accuracy: 0.6902 - val_loss: 1.4528 - val_accuracy: 0.5190
# Epoch 79/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8509 - accuracy: 0.6945 - val_loss: 1.3801 - val_accuracy: 0.5409
# Epoch 80/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.8405 - accuracy: 0.6970 - val_loss: 1.3721 - val_accuracy: 0.5402
# Epoch 81/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8422 - accuracy: 0.6984 - val_loss: 1.3786 - val_accuracy: 0.5407
# Epoch 82/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.8353 - accuracy: 0.7031 - val_loss: 1.3908 - val_accuracy: 0.5417
# Epoch 83/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8214 - accuracy: 0.7060 - val_loss: 1.3904 - val_accuracy: 0.5390
# Epoch 84/100
# 40000/40000 [==============================] - 5s 120us/sample - loss: 0.8205 - accuracy: 0.7043 - val_loss: 1.4070 - val_accuracy: 0.5302
# Epoch 85/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.8137 - accuracy: 0.7088 - val_loss: 1.3913 - val_accuracy: 0.5379
# Epoch 86/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7992 - accuracy: 0.7158 - val_loss: 1.4226 - val_accuracy: 0.5340
# Epoch 87/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7959 - accuracy: 0.7174 - val_loss: 1.4325 - val_accuracy: 0.5290
# Epoch 88/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.7808 - accuracy: 0.7199 - val_loss: 1.3914 - val_accuracy: 0.5463
# Epoch 89/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7789 - accuracy: 0.7199 - val_loss: 1.4428 - val_accuracy: 0.5316
# Epoch 90/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7739 - accuracy: 0.7225 - val_loss: 1.4175 - val_accuracy: 0.5376
# Epoch 91/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7611 - accuracy: 0.7276 - val_loss: 1.4148 - val_accuracy: 0.5327
# Epoch 92/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.7526 - accuracy: 0.7308 - val_loss: 1.4126 - val_accuracy: 0.5414
# Epoch 93/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.7544 - accuracy: 0.7292 - val_loss: 1.4154 - val_accuracy: 0.5341
# Epoch 94/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.7464 - accuracy: 0.7318 - val_loss: 1.4350 - val_accuracy: 0.5378
# Epoch 95/100
# 40000/40000 [==============================] - 5s 121us/sample - loss: 0.7348 - accuracy: 0.7374 - val_loss: 1.4085 - val_accuracy: 0.5396
# Epoch 96/100
# 40000/40000 [==============================] - 5s 118us/sample - loss: 0.7333 - accuracy: 0.7387 - val_loss: 1.4351 - val_accuracy: 0.5327
# Epoch 97/100
# 40000/40000 [==============================] - 5s 115us/sample - loss: 0.7251 - accuracy: 0.7411 - val_loss: 1.4480 - val_accuracy: 0.5408
# Epoch 98/100
# 40000/40000 [==============================] - 5s 116us/sample - loss: 0.7175 - accuracy: 0.7436 - val_loss: 1.5069 - val_accuracy: 0.5217
# Epoch 99/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.7159 - accuracy: 0.7454 - val_loss: 1.4752 - val_accuracy: 0.5307
# Epoch 100/100
# 40000/40000 [==============================] - 5s 117us/sample - loss: 0.7095 - accuracy: 0.7440 - val_loss: 1.4221 - val_accuracy: 0.5441
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ###Evaluation
#
# In the following charts, you could see that the training accuracy does not deviate much from validation accuracy during the early epochs compared to unregularized model.
#
# At later epochs, the overfitting problem came back. A possible solution to this issue would be to implement early stopping.

# %%
_,acc = model_3_reg_best.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_3_reg, acc)
# Out:
# Training accuracy: 74.402
# Validation accuracy: 54.410
# Testing accuracy: 54.840

# %%
# serialize model to JSON
model_json = model_3_reg_best.to_json()
with open("/content/SavedModel/best_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_3_reg_best.save_weights("/content/SavedModel/best_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Early Stopping
#
# Early stopping is a way to stop the neural network from overfitting. In this particular scenario, we will borrow the previous model with dropouts and perform an early stop.

# %% [markdown]
# ### Model 3 (Early Stopping)
#
# The following defines the model and indicate the early stop parameters.
#
# In this case, we set the paramters to monitor validation accuracy, and stop the training if the validation accuracy has not improved over 3 epochs (patience).
#
# The patience is determined through trials. We first set to stop after 1 epoch of no improvement. We realise that the accuracy is quite low, therefore setting it to 5 epochs to get higher validation accuracy.

# %%
earlystop = callbacks.EarlyStopping(patience=3, monitor='val_accuracy', min_delta=0.0001)

model_3_es = tf.keras.models.Sequential([
    Dense(2054, activation='relu', kernel_initializer=init_w,  input_shape= (3072,)),
    Dropout(rate=0.3),
    Dense(1376, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(32, activation='relu', kernel_initializer=init_w),
    Dense(1376, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(2054, activation='relu', kernel_initializer=init_w),
    Dropout(rate=0.3),
    Dense(10, activation = 'softmax')
])

model_3_es.summary()

model_3_es.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_3_es = model_3_es.fit(train_x_scaled, train_y,epochs=epoch,validation_split=0.2,shuffle=True, batch_size=batch_size, callbacks=[earlystop])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 2054)              6311942
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2054)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1376)              2827680
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1376)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                44064
# _________________________________________________________________
# dense_15 (Dense)             (None, 1376)              45408
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1376)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2054)              2828358
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2054)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                20550
# =================================================================
# Total params: 12,078,002
# Trainable params: 12,078,002
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/60
# 40000/40000 [==============================] - 6s 143us/sample - loss: 2.2206 - accuracy: 0.1597 - val_loss: 2.1336 - val_accuracy: 0.2193
# Epoch 2/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 2.0235 - accuracy: 0.2268 - val_loss: 2.0009 - val_accuracy: 0.2306
# Epoch 3/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.9446 - accuracy: 0.2516 - val_loss: 1.8511 - val_accuracy: 0.2957
# Epoch 4/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.8824 - accuracy: 0.2961 - val_loss: 1.8926 - val_accuracy: 0.2981
# Epoch 5/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.8155 - accuracy: 0.3266 - val_loss: 1.8309 - val_accuracy: 0.3344
# Epoch 6/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.7628 - accuracy: 0.3528 - val_loss: 1.6960 - val_accuracy: 0.3801
# Epoch 7/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.7218 - accuracy: 0.3680 - val_loss: 1.6673 - val_accuracy: 0.3982
# Epoch 8/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.6894 - accuracy: 0.3826 - val_loss: 1.7213 - val_accuracy: 0.3767
# Epoch 9/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.6521 - accuracy: 0.3988 - val_loss: 1.6120 - val_accuracy: 0.4230
# Epoch 10/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.6238 - accuracy: 0.4098 - val_loss: 1.6219 - val_accuracy: 0.4144
# Epoch 11/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.5999 - accuracy: 0.4186 - val_loss: 1.5842 - val_accuracy: 0.4364
# Epoch 12/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.5678 - accuracy: 0.4291 - val_loss: 1.5584 - val_accuracy: 0.4420
# Epoch 13/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.5489 - accuracy: 0.4412 - val_loss: 1.5899 - val_accuracy: 0.4349
# Epoch 14/60
# 40000/40000 [==============================] - 5s 118us/sample - loss: 1.5296 - accuracy: 0.4478 - val_loss: 1.5724 - val_accuracy: 0.4489
# Epoch 15/60
# 40000/40000 [==============================] - 5s 115us/sample - loss: 1.5127 - accuracy: 0.4549 - val_loss: 1.5089 - val_accuracy: 0.4633
# Epoch 16/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.4944 - accuracy: 0.4606 - val_loss: 1.4892 - val_accuracy: 0.4701
# Epoch 17/60
# 40000/40000 [==============================] - 5s 114us/sample - loss: 1.4747 - accuracy: 0.4690 - val_loss: 1.4786 - val_accuracy: 0.4735
# Epoch 18/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.4614 - accuracy: 0.4695 - val_loss: 1.4726 - val_accuracy: 0.4712
# Epoch 19/60
# 40000/40000 [==============================] - 5s 117us/sample - loss: 1.4462 - accuracy: 0.4805 - val_loss: 1.4918 - val_accuracy: 0.4763
# Epoch 20/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.4279 - accuracy: 0.4856 - val_loss: 1.5040 - val_accuracy: 0.4591
# Epoch 21/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.4134 - accuracy: 0.4906 - val_loss: 1.4965 - val_accuracy: 0.4721
# Epoch 22/60
# 40000/40000 [==============================] - 5s 116us/sample - loss: 1.3967 - accuracy: 0.4976 - val_loss: 1.4708 - val_accuracy: 0.4724

# %% [markdown]
# ### Evaluation
#
# In the following chart, we could see that not all 60 epochs are completed. The training stops after 23 epochs of no improvement.

# %%
_,acc = model_3_es.evaluate(test_x_scaled, test_y, verbose=0)
plot_history(history_3_es, acc)
# Out:
# Training accuracy: 49.762
# Validation accuracy: 47.240
# Testing accuracy: 47.440

# %% [markdown]
# # Analysis
#
# In this section, we will use the best model we have to run prediction and check if the model have unnecesary bias against certain classes.

# %%
# load json and create model
json_file = open('/content/SavedModel/best_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
best_model = models.model_from_json(loaded_model_json)
# load weights into new model
best_model.load_weights("/content/SavedModel/best_model.h5")
print("Loaded model from disk")


preds = best_model.predict(test_x_scaled, verbose=0)
indexes = tf.argmax(preds, axis=1)
preds_label = indexes.numpy()
samples = [random.randrange(1, 10000, 1) for _ in range(30)]
display_image(reverse_flat(test_x[samples]), test_y[samples], preds_label[samples])
# Out:
# Loaded model from disk

# %% [markdown]
# # References
#
# [1] [Learning Multiple Layers of Features from Tiny Images](https://www.cs.toronto.edu/~kriz/learning-features-2009-TR.pdf), Alex Krizhevsky, 2009.
#
# [2] [Hidden Layers](https://www.heatonresearch.com/2017/06/01/hidden-layers.html), Jeff Heaton, 2017.
#
# [3] [Hyper-parameters in Action! Part II — Weight Initializers](https://towardsdatascience.com/hyper-parameters-in-action-part-ii-weight-initializers-35aee1a28404), Daniel Godoy, 2018.
#
# [4] [A Gentle Introduction to Dropout for Regularizing Deep Neural Networks](https://machinelearningmastery.com/dropout-for-regularizing-deep-neural-networks/), Jason Brownlee, 2018.
